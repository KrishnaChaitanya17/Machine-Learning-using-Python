# %% [markdown]
# # **Basic Programs**

# %% [markdown]
# PROGRAM 1:WRITE A PROGRAM TO FIND AREA OF TRIANGLE

# %%
a,b,c =map(int, input("enter the lengths of triangle:").split())

s=(a+b+c)/2

area=(s*(s-a)*(s-b)*(s-c))**0.5
print('Area of triangle:',area)
# Out:
# enter the lengths of triangle:5 4 3
# Area of triangle: 6.0

# %% [markdown]
# Program 2: Write a program to read the three sides of as triangle and check whether it is equilateral,isosceles or scalene Triangle.

# %%
A=int(input('Enter side1 : '))
B=int(input('Enter side2 : '))
C=int(input('Enter side3 : '))
if (A==B and A==C):
  print("The Given Triangle is equilateral\n")
elif (A==B or B==C or C==A):
  print("The given Triangle is isosceles\n")
else:
      print("The given Triangle is scalene\n");
# Out:
# Enter side1 : 10
# Enter side2 : 12
# Enter side3 : 10
# The given Triangle is isosceles

# %% [markdown]
# for loop example

# %%
n=int(input('Enter a number'))
for i in range(1,n+1):
  print(i)
# Out:
# Enter a number5
# 1
# 2
# 3
# 4
# 5

# %% [markdown]
# # **LIST**

# %% [markdown]
# 1 :Program to read 'n' numbers and count positive,negative and zero among them

# %%
np=nn=nz=0
l=[]
n=int(input('Enter the total no.of numbers '))
for i in range(1,n+1):
  num=int(input('Enter a number '))
  l.append(num)
print(l)
for i in l:
  if i<0:
    nn=nn+1
  elif i>0:
    np=np+1
  else:
    nz=nz+1
print('Positive Count is {0}\n Negative count is {1}\n Zeros are {2}'.format(np,nn,nz))
# Out:
# Enter the total no.of numbers 5
# Enter a number 17
# Enter a number 18
# Enter a number -33
# Enter a number 0
# Enter a number -2
# [17, 18, -33, 0, -2]
# Positive Count is 2
#  Negative count is 2
#  Zeros are 1

# %% [markdown]
# list slicing

# %%
my_list=['c','h','a','i','t','a','n','y','a']
my_list[1:5]
# Out:
# ['h', 'a', 'i', 't']

# %%
my_list[:-3]
# Out:
# ['c', 'h', 'a', 'i', 't', 'a']

# %% [markdown]
# 2 : Read the ages of a list of people into a list.For all ages between 40 to 50,the string 'middle age' should be stored instead.Print the resulting list

# %%
ages=[]
while 1:
  print("Press 0 to stop")
  a=int(input('Enter the age of a person : '))
  ages.append(a)
  if (a==0):
    break
for i in ages:
  print(i3)
for i in range(len(ages)):
  if (ages[i]>=40 and ages[i]<=50):
    ages[i]='Middle Age'
print(ages)
# Out:
# Press 0 to stop
# Enter the age of a person : 18
# Press 0 to stop
# Enter the age of a person : 45
# Press 0 to stop
# Enter the age of a person : 23
# Press 0 to stop
# Enter the age of a person : 19
# Press 0 to stop
# Enter the age of a person : 47
# Press 0 to stop
# Enter the age of a person : 50
# Press 0 to stop
# Enter the age of a person : 12
# Press 0 to stop
# Enter the age of a person : 0
# 18
# 45
# 23
# 19
# 47
# 50
# 12
# 0
# [18, 'Middle Age', 23, 19, 'Middle Age', 'Middle Age', 12, 0]

# %%
ages=[]
nop=int(input('Enter the total no.of people'))
for i in range(nop):
  a=int(input('Enter age '))
  ages.append(a)
print('\nThe Input Ages Are : \n')
for i in ages:
  print(i)
for i in range(len(ages)):
  if (ages[i]>=40 and ages[i]<=50):
    ages[i]='Middle Age'
print(ages)
# Out:
# Enter the total no.of people5
# Enter age 32
# Enter age 19
# Enter age 25
# Enter age 40
# Enter age 45
#
# The Input Ages Are :
#
# 32
# 19
# 25
# 40
# 45
# [32, 19, 25, 'Middle Age', 'Middle Age']

# %% [markdown]
# 3 :Read a list of names.Find how many times a letter 'a' appears in the list

# %%
names=[]
count=0
size=int(input('Enter total number of names '))
for i in range(size):
  n=input('Enter a name ')
  names.append(n)
for i in names:
  for j in i:
    if j=='a':
      count=count+1
print('No.of times letter a occurs is',count)
# Out:
# Enter total number of names 2
# Enter a name krishna
# Enter a name chaitanya
# No.of times letter a occurs is 4

# %% [markdown]
# 4 : Print only vowels present in a given word

# %%
vowels=['a','e','i','o','u']
word=input('Enter word ')
v=[ch for ch in word if ch in vowels]
print(v)
# Out:
# Enter word chaitanya
# ['a', 'i', 'a', 'a']

# %% [markdown]
# 5 :Read a list of integers from the user till the user inputs 000

# %%
inp=[]
square=[]
postive=[]
while(1):
  n=int(input('Enter a number '))
  if n!=000:
    inp.append(n)
  else:
    break  
square=[x**2 for x in inp]
positive=[i for i in inp if i>=0]
print(square)
print(positive)
# Out:
# Enter a number 17
# Enter a number 18
# Enter a number -4
# Enter a number 333
# Enter a number 45
# Enter a number 000
# [289, 324, 16, 110889, 2025]
# [17, 18, 333, 45]

# %% [markdown]
# 6 : Using list comprehension create two lists
# 1)odd - list of odd integers from 1 to 10.
# 2)even-list of even integers from 1 to 10.

# %%
even=[i for i in range(10) if i%2==0]
odd=[i for i in range(10) if i%2!=0]
print(even)
print(odd)
# Out:
# [0, 2, 4, 6, 8]
# [1, 3, 5, 7, 9]

# %% [markdown]
# # **TUPLES**

# %%
age=[]
while(1):
  a=int(input('Enter the age of a person '))
  if a<0:
    break
  else:
    age.append(a)
t=tuple(age)
print(t)
# Out:
# Enter the age of a person 19
# Enter the age of a person 20
# Enter the age of a person -2
# (19, 20)

# %% [markdown]
# Inserting a set of items into a tuple at a specific index

# %%
t=(2,3,4,5,6)
t=t[:2]+(3.1,3.2,3.3,3.4)+t[2:]
print(t)
# Out:
# (2, 3, 3.1, 3.2, 3.3, 3.4, 4, 5, 6)

# %% [markdown]
# 1 . WAP TO CREATE A TUPLE BY SLICING METHOD AND PRINT IT THEN REMOVE A NAME OF PERSON

# %%
t=()
while(1):
  a=input("Enter the name of a person ")
  if a=='AAA':
    break
  else:
    t=t+(a,)
print(t)
unique=[]
for i in t:
  if i not in unique:
    unique.append(i)
    print('The name {0} occurs {1} times in the input'.format(i,t.count((i))))
# Out:
# Enter the name of a person krishna
# Enter the name of a person chaitanya
# Enter the name of a person chakri
# Enter the name of a person aaa
# Enter the name of a person AAA
# ('krishna', 'chaitanya', 'chakri', 'aaa')
# The name krishna occurs 1 times in the input
# The name chaitanya occurs 1 times in the input
# The name chakri occurs 1 times in the input
# The name aaa occurs 1 times in the input

# %% [markdown]
# 2 :Most occuring

# %%
import statistics
tup=()
while(1):
  name=input("Enter the name :")
  if name=='AAA':
    break
  else:
    tup=tup+(name,)
print('Most frequent name is ',statistics.mode(tup))
# Out:
# Enter the name :Krishna
# Enter the name :Chaitanya
# Enter the name :Krishna
# Enter the name :AAA
# Most frequent name is  Krishna

# %% [markdown]
# 3 :removing name from the tuple

# %%
t=()
while(1):
  a=input("Enter the name of a person ")
  if a=='AAA':
    break
  else:
    t=t+(a,)
remove=input('Enter the name to be removed')
for i in range(len(t)):
  if t[i]==remove:
    t=t[:i]+t[i+1:]
    break
print("The list after removing {0} is {1}".format(remove,t))
# Out:
# Enter the name of a person Krishna
# Enter the name of a person Chaitanya
# Enter the name of a person AAA
# Enter the name to be removedKrishna
# The list after removing Krishna is ('Chaitanya',)

# %% [markdown]
# 4 :Shopping List(name and quantity)

# %%
shopping_list=[]
item=()
while(1):
  a=eval(input("Enter the name and quantity of an item as a ()"))
  if a==():
    break
  else:
    shopping_list.append(a)
print("The Shopping List",shopping_list)
# Out:
# Enter the name and quantity of an item as a ()('bread',10)
# Enter the name and quantity of an item as a ()('egg',12)
# Enter the name and quantity of an item as a ()('butter',4)
# Enter the name and quantity of an item as a ()()
# The Shopping List [('bread', 10), ('egg', 12), ('butter', 4)]

# %% [markdown]
# 5 :WAPP to print sorted fruit list

# %%
fruit_list=[]
item=()
while(1):
  a=eval(input("Enter the name and weight of each fruit as a ()"))
  if a==():
    break
  else:
    fruit_list.append(a)
print("The Shopping List",fruit_list)
sorted_names=sorted(fruit_list)
print("The list sorted in alphabetical order of fruit names is",sorted_names)
# Out:
# Enter the name and weight of each fruit as a ()('grapes',3)
# Enter the name and weight of each fruit as a ()('apples',4)
# Enter the name and weight of each fruit as a ()('banana',2)
# Enter the name and weight of each fruit as a ()()
# The Shopping List [('grapes', 3), ('apples', 4), ('banana', 2)]
# The list sorted in alphabetical order of fruit names is [('apples', 4), ('banana', 2), ('grapes', 3)]

# %% [markdown]
# 6 : sort the list in ascending order

# %%
import operator
fruit_list=[]
item=()
while(1):
  a=eval(input("Enter the name and weight of each fruit as a ()"))
  if a==():
    break
  else:
    fruit_list.append(a)
print("The Shopping List",fruit_list)
sorted_asc_weights=sorted(fruit_list,key=operator.itemgetter(1))
print("The list sorted in ascending order of fruit weights is ",sorted_asc_weights)
# Out:
# Enter the name and weight of each fruit as a ()('kiwi',20)
# Enter the name and weight of each fruit as a ()('orange',30)
# Enter the name and weight of each fruit as a ()('papaya',25)
# Enter the name and weight of each fruit as a ()()
# The Shopping List [('kiwi', 20), ('orange', 30), ('papaya', 25)]
# The list sorted in ascending order of fruit weights is  [('kiwi', 20), ('papaya', 25), ('orange', 30)]

# %% [markdown]
# # **DICTIONARY**

# %% [markdown]
# 1.Given an integer number 'n', wap to generate a dictionary with (i,i*i) such that I is an Integer between 1 and n(both included). The program should then print the dictionary.
#
# intput/Output
# Enter a number 5
# {1: 1, 2: 4, 3: 9, 4: 16, 5:25}

# %%
n = int(input("Enter a number "))
d = dict()
for i in range(1,n+1):
  d[i] = i*i
print(d)
# Out:
# Enter a number 5
# {1: 1, 2: 4, 3: 9, 4: 16, 5: 25}

# %% [markdown]
# 2.Wap to read a list of list having the name of the day and the corresponding temp of days in a week
# EX.temps= [['sun',68.2], ['Wed',30.5]]

# %%
temp_dict={} #dictinoary initialized
temp_list=[] #list initialized
for i in range(2):
    day_temp=eval(input("enter a day and temperature as a list"))
    temp_list.append(day_temp)
print("The input list is",temp_list)
temp_dict=dict(temp_list) #converting list to dictinoary
print(temp_dict)
day=input('Enter a day to add : ')
if day in temp_dict:
    print("Day already exists")
else:
    temp=float(input("enter a temp"))
    temp_dict[day]=temp
print("Updated temperatures")
print(temp_dict)
# Out:
# enter a day and temperature as a list('mon',30.6)
# enter a day and temperature as a list('Tue',40.3)
# The input list is [('mon', 30.6), ('Tue', 40.3)]
# {'mon': 30.6, 'Tue': 40.3}
# Enter a day to add : Wed
# enter a temp29.7
# Updated temperatures
# {'mon': 30.6, 'Tue': 40.3, 'Wed': 29.7}

# %% [markdown]
# 3. Write a program which initializes a dictionary having each day and its temp.The program should return a list of days on which temp was between 70 and 79 degrees

# %%
temps = {'sun':68.8, 'mon':70.2, 'wed':71.8, 'thur':73.2, 'fri':75.6, 'sat':74.0}

days=[]
for d in temps:
  if temps[d] >=70 and temps[d]<=79:
    days.append(d)

print('Days in which average temperature is between 70 and 79')
print(days)
# Out:
# Days in which average temperature is between 70 and 79
# ['mon', 'wed', 'thur', 'fri', 'sat']

# %%
d ={'even':0, 'odd':0}
while(1):
  x = int(input("Enter the number"))
  if x==-1:
    break

  if (x%2 == 0):
    d['even']=d['even']+1
    print(d)
  else:
    d['odd']=d['odd']+1
    print(d)
# Out:
# Enter the number11
# {'even': 0, 'odd': 1}
# Enter the number22
# {'even': 1, 'odd': 1}
# Enter the number1
# {'even': 1, 'odd': 2}
# Enter the number-1

# %% [markdown]
# 5.Read any number of int values from the user till the user inputs -1.Every input integer number 'n' has to be placed in the list whose key is given by n%9.

# %%
d ={0:[], 1:[], 2:[], 3:[], 4:[], 5:[], 6:[], 7:[], 8:[]}
while (1):
  x = int(input("Enter the value of n "))
  if x == -1:
    break
  else:
    key= x%9
    d[key].append(x)
    print(d)
# Out:
# Enter the value of n 18
# {0: [18], 1: [], 2: [], 3: [], 4: [], 5: [], 6: [], 7: [], 8: []}
# Enter the value of n 19
# {0: [18], 1: [19], 2: [], 3: [], 4: [], 5: [], 6: [], 7: [], 8: []}
# Enter the value of n 17
# {0: [18], 1: [19], 2: [], 3: [], 4: [], 5: [], 6: [], 7: [], 8: [17]}
# Enter the value of n -1

# %% [markdown]
# 6.Create dictionary of inputs students,marks
#
# 1.Total no.of students in class.
#
# 2.Average of class
#
# 3.Topper of the class

# %%
import operator
students = eval(input("Enter the NAME and MARK of each student as a{}"))
print("The student dictionary is ",students)
print("The number of students are ",len(students))

#to find class average
sum=0
for k in students:
  sum=sum+students[k]
class_average = sum/len(students)
print("The class average is = ",class_average)

#to find no.of students above average
count=0
a=[]
for k in students:
  if students[k]>class_average:
    a.append(k)
    count=count+1
print("The number of students above class average is ",count, "They are ",a)

# to find the topper of the class
out = sorted(students.items(), key=operator.itemgetter(1), reverse=1)
topper=out[0][0]
print("The topper of the class is ",topper)

#to implement recheck
recheck_name = input("Who has applied for recheck?")
new_mark = int(input("What is the new marks?"))
students[recheck_name]=new_mark
print("The dictionary after rechecks is ",students)
# Out:
# Enter the NAME and MARK of each student as a{}{"Krishna":89,"Chaitanya":95,"Chinna":85}
# The student dictionary is  {'Krishna': 89, 'Chaitanya': 95, 'Chinna': 85}
# The number of students are  3
# The class average is =  89.66666666666667
# The number of students above class average is  1 They are  ['Chaitanya']
# The topper of the class is  Chaitanya
# Who has applied for recheck?Chinna
# What is the new marks?93
# The dictionary after rechecks is  {'Krishna': 89, 'Chaitanya': 95, 'Chinna': 93}

# %% [markdown]
# 7.Create a dictionary using comprehension from sequences.

# %%
keys=['a','b','c']
values=[1,2,3]
{i:j for(i,j) in zip(keys,values)}
# Out:
# {'a': 1, 'b': 2, 'c': 3}

# %% [markdown]
# # **Data Frame**

# %%
import pandas as pd
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("/content/empdata-3.csv")
df
# Out:
#    Empid           Ename    Salary         DOJ
# 0   1001          Ganesh   1000.00  10-10-2000
# 1   1002            Anil  23000.50   3/20/2002
# 2   1003          Gaurav       NaN  03-03-2002
# 3   1004    Hema Chandra  16500.50  09-10-2000
# 4   1005  Laxmi Prasanna  12000.75  10-08-2000
# 5   1006          Anant    9999.99  09-09-1999

# %%
df.shape
# Out:
# (6, 4)

# %%
df.isnull().sum()
# Out:
# Empid     0
# Ename     0
# Salary    1
# DOJ       0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6 entries, 0 to 5
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Empid   6 non-null      int64
#  1   Ename   6 non-null      object
#  2   Salary  5 non-null      float64
#  3   DOJ     6 non-null      object
# dtypes: float64(1), int64(1), object(2)
# memory usage: 320.0+ bytes

# %%
df['Ename'].value_coun

# %%
df.describe()
# Out:
#              Empid        Salary
# count     6.000000      5.000000
# mean   1003.500000  12500.348000
# std       1.870829   8139.622234
# min    1001.000000   1000.000000
# 25%    1002.250000   9999.990000
# 50%    1003.500000  12000.750000
# 75%    1004.750000  16500.500000
# max    1006.000000  23000.500000

# %%
#to retrieve range of rows
df[2:5]
# Out:
#    Empid           Ename    Salary         DOJ
# 2   1003          Gaurav       NaN  03-03-2002
# 3   1004    Hema Chandra  16500.50  09-10-2000
# 4   1005  Laxmi Prasanna  12000.75  10-08-2000

# %%
#to retrieve range of rows
df[::2]
# Out:
#    Empid           Ename    Salary         DOJ
# 0   1001          Ganesh   1000.00  10-10-2000
# 2   1003          Gaurav       NaN  03-03-2002
# 4   1005  Laxmi Prasanna  12000.75  10-08-2000

# %%
#to retrieve columns names
df.columns
# Out:
# Index(['Empid', 'Ename', 'Salary', 'DOJ'], dtype='object')

# %%
#to retrieve column data
df.Empid
# Out:
# 0    1001
# 1    1002
# 2    1003
# 3    1004
# 4    1005
# 5    1006
# Name: Empid, dtype: int64

# %%
df[df.Salary > 20000]
# Out:
#    Empid Ename   Salary        DOJ
# 1   1002  Anil  23000.5  3/20/2002

# %%
df[["Empid","Ename"]][df.Salary < 20000]
# Out:
#    Empid           Ename
# 0   1001          Ganesh
# 3   1004    Hema Chandra
# 4   1005  Laxmi Prasanna
# 5   1006          Anant

# %%
df[df.Salary == df.Salary.max()]
# Out:
#    Empid Ename   Salary        DOJ
# 1   1002  Anil  23000.5  3/20/2002

# %%
df1=df.sort_values("Salary",ascending=False)
df1
# Out:
#    Empid           Ename    Salary         DOJ
# 1   1002            Anil  23000.50   3/20/2002
# 3   1004    Hema Chandra  16500.50  09-10-2000
# 4   1005  Laxmi Prasanna  12000.75  10-08-2000
# 5   1006          Anant    9999.99  09-09-1999
# 0   1001          Ganesh   1000.00  10-10-2000
# 2   1003          Gaurav       NaN  03-03-2002

# %%
df1=df.sort_values(by=["DOJ","Salary"],ascending=[False,True])
df1
# Out:
#    Empid           Ename    Salary         DOJ
# 1   1002            Anil  23000.50   3/20/2002
# 0   1001          Ganesh   1000.00  10-10-2000
# 4   1005  Laxmi Prasanna  12000.75  10-08-2000
# 3   1004    Hema Chandra  16500.50  09-10-2000
# 5   1006          Anant    9999.99  09-09-1999
# 2   1003          Gaurav       NaN  03-03-2002

# %% [markdown]
# **Data Cleaning**

# %%
df1.fillna(0)
# Out:
#    Empid           Ename    Salary         DOJ
# 1   1002            Anil  23000.50   3/20/2002
# 0   1001          Ganesh   1000.00  10-10-2000
# 4   1005  Laxmi Prasanna  12000.75  10-08-2000
# 3   1004    Hema Chandra  16500.50  09-10-2000
# 5   1006          Anant    9999.99  09-09-1999
# 2   1003          Gaurav      0.00  03-03-2002

# %%
df1=df.fillna({"Ename":"Name is Missing","Salary":0.0,"DOJ":"00-00-0000"})
df1
# Out:
#    Empid           Ename    Salary         DOJ
# 0   1001          Ganesh   1000.00  10-10-2000
# 1   1002            Anil  23000.50   3/20/2002
# 2   1003          Gaurav      0.00  03-03-2002
# 3   1004    Hema Chandra  16500.50  09-10-2000
# 4   1005  Laxmi Prasanna  12000.75  10-08-2000
# 5   1006          Anant    9999.99  09-09-1999

# %%
df1.dropna()
df1
# Out:
#    Empid           Ename    Salary         DOJ
# 0   1001          Ganesh   1000.00  10-10-2000
# 1   1002            Anil  23000.50   3/20/2002
# 2   1003          Gaurav      0.00  03-03-2002
# 3   1004    Hema Chandra  16500.50  09-10-2000
# 4   1005  Laxmi Prasanna  12000.75  10-08-2000
# 5   1006          Anant    9999.99  09-09-1999

# %% [markdown]
# # **Question 1**

# %%
df2=pd.read_csv("/content/sampledata_orders.csv")

# %%
#i)print the top 5 rows and columns
df2.head(5)
# Out:
#    Row ID  Order ID  ... Product Base Margin   Ship Date
# 0       1         3  ...                0.80  10/20/2010
# 1      49       293  ...                0.58   10/2/2012
# 2      50       293  ...                0.39   10/3/2012
# 3      80       483  ...                0.58   7/12/2011
# 4      85       515  ...                0.50   8/30/2010
#
# [5 rows x 21 columns]

# %%
df2.tail(5)
# Out:
#       Row ID  Order ID  ... Product Base Margin  Ship Date
# 8394    7765     55558  ...                0.65   8/9/2010
# 8395    7766     55558  ...                0.38  8/11/2010
# 8396    7906     56550  ...                0.41  4/10/2011
# 8397    7907     56550  ...                0.56   4/9/2011
# 8398    7914     56581  ...                0.65  2/11/2009
#
# [5 rows x 21 columns]

# %%
#ii)print all columns names
df2.columns
# Out:
# Index(['Row ID', 'Order ID', 'Order Date', 'Order Priority', 'Order Quantity',
#        'Sales', 'Discount', 'Ship Mode', 'Profit', 'Unit Price',
#        'Shipping Cost', 'Customer Name', 'Province', 'Region',
#        'Customer Segment', 'Product Category', 'Product Sub-Category',
#        'Product Name', 'Product Container', 'Product Base Margin',
#        'Ship Date'],
#       dtype='object')

# %%
#iii)print the all row index ranges
df2.shape
# Out:
# (8399, 21)

# %%
df2.index
# Out:
# RangeIndex(start=0, stop=8399, step=1)

# %%
#iv)Print the Order Quantity column(top 5 values)
df2['Order Quantity'].head(5)
# Out:
# 0     6
# 1    49
# 2    27
# 3    30
# 4    19
# Name: Order Quantity, dtype: int64

# %%
#v)Print the Sales column (top 10 values)
df2['Sales'].head(10)
# Out:
# 0      261.5400
# 1    10123.0200
# 2      244.5700
# 3     4965.7595
# 4      394.2700
# 5      146.6900
# 6       93.5400
# 7      905.0800
# 8     2781.8200
# 9      228.4100
# Name: Sales, dtype: float64

# %%
#vi)Print the row with id:50
df2[df2['Row ID']==50]
# Out:
#    Row ID  Order ID  ... Product Base Margin  Ship Date
# 2      50       293  ...                0.39  10/3/2012
#
# [1 rows x 21 columns]

# %%
#vii)print the 3rd row
df2.iloc[3]
# Out:
# Row ID                                            80
# Order ID                                         483
# Order Date                                 7/10/2011
# Order Priority                                  High
# Order Quantity                                    30
# Sales                                        4965.76
# Discount                                        0.08
# Ship Mode                                Regular Air
# Profit                                       1198.97
# Unit Price                                    195.99
# Shipping Cost                                   3.99
# Customer Name                          Clay Rozendal
# Province                                     Nunavut
# Region                                       Nunavut
# Customer Segment                           Corporate
# Product Category                          Technology
# Product Sub-Category    Telephones and Communication
# Product Name                                    R380
# ...

# %%
#viii. Print the Order Quantity, Sales, Discount and Profit of the 2nd,4th, 6th and 8th row
df2[2:10:2][["Order Quantity","Sales","Discount","Profit"]]
# Out:
#    Order Quantity    Sales  Discount  Profit
# 2              27   244.57      0.01   46.71
# 4              19   394.27      0.08   30.94
# 6              12    93.54      0.03  -54.04
# 8              21  2781.82      0.07 -695.26

# %%
#ix. Print the Order Quantity, Sales, Discount and Profit of orders with discount > 10%
df2[df2['Discount']> 0.1] [['Order Quantity', 'Sales','Discount','Profit']]
# Out:
#       Order Quantity    Sales  Discount  Profit
# 18                11  663.784      0.25 -481.04
# 237               22  338.520      0.21  -17.75
# 1321              43  586.110      0.11   98.44
# 1383               1   27.960      0.17   -9.13
# 1454              49  651.900      0.16  -74.51

# %%
#x.print the production cost
df2['Sales']-df2['Profit']
# Out:
# 0        474.7900
# 1       9665.2100
# 2        197.8600
# 3       3766.7895
# 4        363.3300
#           ...
# 8394    1617.2200
# 8395     370.3200
# 8396     480.7300
# 8397     629.0775
# 8398    1445.5800
# Length: 8399, dtype: float64

# %% [markdown]
# # **SLR**

# %% [markdown]
# Simple Linear Regression Using (OLS) Ordinary Least Squares method. Develop a regression model to predict Salary based on Percentage in Grade 10.

# %% [markdown]
# **1.Importing the dataset**

# %%
#import the data from MBA Salary.csv
import pandas as pd
import numpy as np
mba_salary_df=pd.read_csv("/content/MBA Salary.csv")
mba_salary_df.head(10)
# Out:
#    S. No.  Percentage in Grade 10  Salary
# 0       1                   62.00  270000
# 1       2                   76.33  200000
# 2       3                   72.00  240000
# 3       4                   60.00  250000
# 4       5                   61.00  180000
# 5       6                   55.00  300000
# 6       7                   70.00  260000
# 7       8                   68.00  235000
# 8       9                   82.80  425000
# 9      10                   59.00  240000

# %%
#print information about the dataset
mba_salary_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 3 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   S. No.                  50 non-null     int64
#  1   Percentage in Grade 10  50 non-null     float64
#  2   Salary                  50 non-null     int64
# dtypes: float64(1), int64(2)
# memory usage: 1.3 KB

# %%
mba_salary_df.shape
# Out:
# (50, 3)

# %% [markdown]
# **2. Creating feature set X and the outcome variable Y.**

# %% [markdown]
# The statsmodel library is used for building statistical models. OLS API in statsmodel.api is used to estimate the parameters of simple linear regression. It takes two parameters Y and X. IN this data Y is Salary and X is Percentage in Grade 10. The OLS model estimates only the coefficient of X (Beta 1 or slope). To estimate Beta 0, a constant term of 1 needs to be added as a seperate column. This parameter is the intercept term.

# %%
import statsmodels.api as sm
X = sm.add_constant(mba_salary_df['Percentage in Grade 10'])
X.head(5)
# Out:
# /usr/local/lib/python3.7/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm
#    const  Percentage in Grade 10
# 0    1.0                   62.00
# 1    1.0                   76.33
# 2    1.0                   72.00
# 3    1.0                   60.00
# 4    1.0                   61.00

# %% [markdown]
# **3.Create outcome Variable Y**

# %%
Y = mba_salary_df['Salary']
Y.head()
# Out:
# 0    270000
# 1    200000
# 2    240000
# 3    250000
# 4    180000
# Name: Salary, dtype: int64

# %% [markdown]
# **4. Split dataset into training and validation sets. Use 80% for training and 20% for validating**

# %%
from sklearn.model_selection import train_test_split
train_X,test_X,train_y,test_y=train_test_split(X,Y,train_size=0.8,random_state=5)

# %% [markdown]
# **5.Fit the model**

# %%
mba_salary_lm = sm.OLS(train_y,train_X).fit()

# %% [markdown]
# The fit() method on OLS, estimates the parameters and returns the model information such as model parameters(coefficients), acccuracy measures and residual values to the varibale mba_salary_sm

# %% [markdown]
# **6.Print the estimated parameters**

# %%
print(mba_salary_lm.params)
# Out:
# const                     26283.435050
# Percentage in Grade 10     3651.167836
# dtype: float64

# %% [markdown]
# Hence Beta 0=26283.435050 and Beta 1=3651.167836.The estimated model is MBA Salary=26283.435050 + 3651.167836(Percentage in Grade 10)

# %% [markdown]
# **7.Model Diagnostics - Printing the coefficient of determination R-Square**

# %%
print(mba_salary_lm.summary2())
# Out:
#                           Results: Ordinary least squares
# ...
# Model:                    OLS                   Adj. R-squared:          0.189
# Dependent Variable:       Salary                AIC:                     1012.2564
# Date:                     2021-09-23 04:31      BIC:                     1015.6341
# No. Observations:         40                    Log-Likelihood:          -504.13
# Df Model:                 1                     F-statistic:             10.11
# Df Residuals:             38                    Prob (F-statistic):      0.00293
# R-squared:                0.210                 Scale:                   5.4551e+09
# -----------------------------------------------------------------------------------
#                          Coef.     Std.Err.    t    P>|t|     [0.025       0.975]
# -----------------------------------------------------------------------------------
# const                  26283.4351 73928.3696 0.3555 0.7242 -123376.7249 175943.5950
# ...

# %% [markdown]
# Hence R Square of the model is 0.210. So the model explains 21% of the variation in salary.

# %% [markdown]
# **8. Model Diagnostics - Residual Analysis**

# %% [markdown]
# Variance of the residual has to be constant across different values of the predicted value (Y') - a property known as homoscedasticity. A non-constant variance of the residuals is known as heteroscedasticity - not desired. If there is heteroscedasticity, a residual plot between standardised residual values and standardised predicted values, will be funnel shaped. To standardize, subtract from mean and divide by standard deviation

# %%
import matplotlib.pyplot as plt

def get_std_values(vals):
  return(vals - vals.mean())/vals.std()
x_axis=get_std_values(mba_salary_lm.fittedvalues)
y_axis=get_std_values(mba_salary_lm.resid)
plt.scatter(x_axis,y_axis)
plt.xlabel("Standardised Predicted Values")
plt.ylabel("Standardised Residual Values")
plt.title("Residual Plot")
plt.show()

# %% [markdown]
# The residual plot is not funnel shaped.Hence residuals have constant variance.

# %% [markdown]
# **9. Model Diagnostics - Oulier Detection.**

# %% [markdown]
# Outliers are observations whose values show a large deviation from the mean value. Their presence can have a significant influence on the values of the regression coefficients. Hence we use Z-Score to identify their existence in the data. Any obervation with an Z-Score of more than 3.0 is an outlier.

# %%
from scipy.stats import zscore
mba_salary_df['z_score_salary']=zscore(mba_salary_df.Salary)
mba_salary_df.head()
# Out:
#    S. No.  Percentage in Grade 10  Salary  z_score_salary
# 0       1                   62.00  270000        0.155481
# 1       2                   76.33  200000       -0.766241
# 2       3                   72.00  240000       -0.239543
# 3       4                   60.00  250000       -0.107868
# 4       5                   61.00  180000       -1.029590

# %%
mba_salary_df[(mba_salary_df.z_score_salary > 3.0)| (mba_salary_df.z_score_salary < -3.0)]
# Out:
# Empty DataFrame
# Columns: [S. No., Percentage in Grade 10, Salary, z_score_salary]
# Index: []

# %% [markdown]
# Hence there is no outliner

# %% [markdown]
# **10. Model Diagnostics - Finding highly influential Observations using Cooks's distance.**

# %% [markdown]
#  This distance measures how much the predicted value of the dependent variable changes for all observations on the sample when a particular observation is removed from the sample while estimating the regression parameters. get_influence() returns the influence of each observations and cook_distance variable provides Cook's distance measures. An observation with Cook's distance of more than 1 is highly influential.

# %%
mba_influence = mba_salary_lm.get_influence()
(c,p) = mba_influence.cooks_distance
plt.stem(np.arange(len(train_X)),np.round(c,3))
plt.xlabel("Row Index")
plt.ylabel("Cook Distance")
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: UserWarning: In Matplotlib 3.3 individual lines on a stem plot will be added as a LineCollection instead of individual lines. This significantly improves the performance of a stem plot. To remove this warning and switch to the new behaviour, set the "use_line_collection" keyword argument to True.
#   This is separate from the ipykernel package so we can avoid doing imports until

# %% [markdown]
# There is no observation with Cooks's distance > 1.Hence,none of them are influential.

# %% [markdown]
# **11.Making predictions on validation set and measuring accuracy - R-Squared and RMSE**

# %%
from sklearn.metrics import r2_score,mean_squared_error
pred_y = mba_salary_lm.predict(test_X)
print('R2 Score =',np.abs(r2_score(test_y,pred_y)))
print('RMSE =',np.sqrt(mean_squared_error(test_y,pred_y)))
# Out:
# R2 Score = 0.45367053807269775
# RMSE = 61393.28235186985

# %% [markdown]
# # **MLR**

# %% [markdown]
# 1.Load the IPL data set

# %%
import pandas as pd
import numpy as np
ipl_df=pd.read_csv("/content/IPL IMB381IPL2013-1.csv")
ipl_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 130 entries, 0 to 129
# Data columns (total 26 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Sl.NO.         130 non-null    int64
#  1   PLAYER NAME    130 non-null    object
#  2   AGE            130 non-null    int64
#  3   COUNTRY        130 non-null    object
#  4   TEAM           130 non-null    object
#  5   PLAYING ROLE   130 non-null    object
#  6   T-RUNS         130 non-null    int64
#  7   T-WKTS         130 non-null    int64
#  8   ODI-RUNS-S     130 non-null    int64
#  9   ODI-SR-B       130 non-null    float64
#  10  ODI-WKTS       130 non-null    int64
#  11  ODI-SR-BL      130 non-null    float64
#  12  CAPTAINCY EXP  130 non-null    int64
#  13  RUNS-S         130 non-null    int64
#  14  HS             130 non-null    int64
#  15  AVE            130 non-null    float64
#  16  SR-B           130 non-null    float64
# ...

# %%
ipl_df.shape
# Out:
# (130, 26)

# %%
ipl_df.head()
# Out:
#    Sl.NO.   PLAYER NAME  AGE  ... AUCTION YEAR BASE PRICE SOLD PRICE
# 0       1   Abdulla, YA    2  ...         2009      50000      50000
# 1       2  Abdur Razzak    2  ...         2008      50000      50000
# 2       3   Agarkar, AB    2  ...         2008     200000     350000
# 3       4     Ashwin, R    1  ...         2011     100000     850000
# 4       5  Badrinath, S    2  ...         2011     100000     800000
#
# [5 rows x 26 columns]

# %% [markdown]
# 2.Display the initial 10 cloumns for the first records.

# %%
ipl_df.iloc[0:5,0:10]
# Out:
#    Sl.NO.   PLAYER NAME  AGE COUNTRY  ... T-RUNS T-WKTS  ODI-RUNS-S  ODI-SR-B
# 0       1   Abdulla, YA    2      SA  ...      0      0           0      0.00
# 1       2  Abdur Razzak    2     BAN  ...    214     18         657     71.41
# 2       3   Agarkar, AB    2     IND  ...    571     58        1269     80.62
# 3       4     Ashwin, R    1     IND  ...    284     31         241     84.56
# 4       5  Badrinath, S    2     IND  ...     63      0          79     45.93
#
# [5 rows x 10 columns]

# %%
ipl_df.columns
# Out:
# Index(['Sl.NO.', 'PLAYER NAME', 'AGE', 'COUNTRY', 'TEAM', 'PLAYING ROLE',
#        'T-RUNS', 'T-WKTS', 'ODI-RUNS-S', 'ODI-SR-B', 'ODI-WKTS', 'ODI-SR-BL',
#        'CAPTAINCY EXP', 'RUNS-S', 'HS', 'AVE', 'SR-B', 'SIXERS', 'RUNS-C',
#        'WKTS', 'AVE-BL', 'ECON', 'SR-BL', 'AUCTION YEAR', 'BASE PRICE',
#        'SOLD PRICE'],
#       dtype='object')

# %% [markdown]
# 3.use only the following features to predict the players sold price.

# %%
X_features = ['AGE', 'COUNTRY', 'PLAYING ROLE', 'T-RUNS', 'T-WKTS', 'ODI-RUNS-S', 'ODI-SR-B', 'ODI-WKTS', 'ODI-SR-BL','CAPTAINCY EXP', 'RUNS-S', 'HS', 'AVE', 'SR-B','SIXERS', 'RUNS-C', 'WKTS', 'AVE-BL', 'ECON', 'SR-BL']

# %% [markdown]
# 4.Some of these features are categorical.So encode them using one-hot encoding.A categorical feature with k values s encoded using (k-1)binary/dummy features.

# %%
categorical_features = ['AGE', 'COUNTRY','PLAYING ROLE','CAPTAINCY EXP']
ipl_encoded_df = pd.get_dummies(ipl_df[X_features], columns=categorical_features, drop_first = True)
#print the columns in the encoded dataframe
X_features = ipl_encoded_df.columns
print(X_features)
# Out:
# Index(['T-RUNS', 'T-WKTS', 'ODI-RUNS-S', 'ODI-SR-B', 'ODI-WKTS', 'ODI-SR-BL',
#        'RUNS-S', 'HS', 'AVE', 'SR-B', 'SIXERS', 'RUNS-C', 'WKTS', 'AVE-BL',
#        'ECON', 'SR-BL', 'AGE_2', 'AGE_3', 'COUNTRY_BAN', 'COUNTRY_ENG',
#        'COUNTRY_IND', 'COUNTRY_NZ', 'COUNTRY_PAK', 'COUNTRY_SA', 'COUNTRY_SL',
#        'COUNTRY_WI', 'COUNTRY_ZIM', 'PLAYING ROLE_Batsman',
#        'PLAYING ROLE_Bowler', 'PLAYING ROLE_W. Keeper', 'CAPTAINCY EXP_1'],
#       dtype='object')

# %% [markdown]
# 5.Add the constant column to estimate Beta 0 using statsmodel library.Split the dataset into Train and Vadilation Sets

# %%
import statsmodels.api as sm
from sklearn.model_selection import train_test_split
X = sm.add_constant(ipl_encoded_df)
Y = ipl_df['SOLD PRICE']

train_X, test_X, train_y, test_y = train_test_split(X,Y,train_size = 0.8, random_state = 42)
#random_state is set to the seed 42 randomly. This is to reproduce the result across the runs. 
#Also it ensures same records go for training and validation


#BETA is intercept of the model

# %% [markdown]
# 6.Bulid the model on training set

# %%
ipl_mlr_model1 = sm.OLS(train_y,train_X).fit()
ipl_mlr_model1.summary2()
# Out:
# <class 'statsmodels.iolib.summary2.Summary'>
# """
#                             Results: Ordinary least squares
# ...
# Model:                     OLS                     Adj. R-squared:            0.362
# Dependent Variable:        SOLD PRICE              AIC:                       2965.2841
# Date:                      2021-10-07 04:24        BIC:                       3049.9046
# No. Observations:          104                     Log-Likelihood:            -1450.6
# Df Model:                  31                      F-statistic:               2.883
# Df Residuals:              72                      Prob (F-statistic):        0.000114
# R-squared:                 0.554                   Scale:                     1.1034e+11
# ----------------------------------------------------------------------------------------
#                           Coef.       Std.Err.     t    P>|t|     [0.025       0.975]
# ...

# %% [markdown]
# 7.Validate this model on the test data. Find the regression parameters, r2_score and RMSE of this model1

# %%
from sklearn.metrics import r2_score,mean_squared_error
import numpy as np

pred_y = ipl_mlr_model1.predict(test_X)
print("The r2_score of the model is ",np.abs(r2_score(test_y,pred_y)))
print("The RMSE of the trained model is", np.sqrt(mean_squared_error(test_y, pred_y)))
print("The model parameters are")
print(ipl_mlr_model1.params)
# Out:
# The r2_score of the model is  0.31915984500757244
# The RMSE of the trained model is 304522.9980115467
# The model parameters are
# const                     375827.199059
# T-RUNS                       -53.789030
# T-WKTS                      -132.596723
# ODI-RUNS-S                    57.959956
# ODI-SR-B                    -524.144970
# ODI-WKTS                     815.394424
# ODI-SR-BL                   -773.309199
# RUNS-S                       114.720547
# HS                         -5516.335398
# AVE                        21560.275955
# SR-B                       -1324.721784
# SIXERS                      4264.100109
# RUNS-C                        69.825020
# WKTS                        3075.242189
# AVE-BL                      5182.933487
# ECON                       -6820.778058
# SR-BL                      -7658.809364
# AGE_2                    -230767.646329
# AGE_3                    -216827.080829
# COUNTRY_BAN              -122103.519643
# ...

# %% [markdown]
# 8.Find the variables which are statistically significant in influencing the response variable. If the p-value of a variable is less than the significance value(alpha = 0.05), it is an influencing variables.

# %%
s = ipl_mlr_model1.pvalues
print(s.index)
# Out:
# Index(['const', 'T-RUNS', 'T-WKTS', 'ODI-RUNS-S', 'ODI-SR-B', 'ODI-WKTS',
#        'ODI-SR-BL', 'RUNS-S', 'HS', 'AVE', 'SR-B', 'SIXERS', 'RUNS-C', 'WKTS',
#        'AVE-BL', 'ECON', 'SR-BL', 'AGE_2', 'AGE_3', 'COUNTRY_BAN',
#        'COUNTRY_ENG', 'COUNTRY_IND', 'COUNTRY_NZ', 'COUNTRY_PAK', 'COUNTRY_SA',
#        'COUNTRY_SL', 'COUNTRY_WI', 'COUNTRY_ZIM', 'PLAYING ROLE_Batsman',
#        'PLAYING ROLE_Bowler', 'PLAYING ROLE_W. Keeper', 'CAPTAINCY EXP_1'],
#       dtype='object')

# %%
impt_vars = list(s.index)  #s.index returns the variable names of the pandas series s. 
print(impt_vars)
# Out:
# ['const', 'T-RUNS', 'T-WKTS', 'ODI-RUNS-S', 'ODI-SR-B', 'ODI-WKTS', 'ODI-SR-BL', 'RUNS-S', 'HS', 'AVE', 'SR-B', 'SIXERS', 'RUNS-C', 'WKTS', 'AVE-BL', 'ECON', 'SR-BL', 'AGE_2', 'AGE_3', 'COUNTRY_BAN', 'COUNTRY_ENG', 'COUNTRY_IND', 'COUNTRY_NZ', 'COUNTRY_PAK', 'COUNTRY_SA', 'COUNTRY_SL', 'COUNTRY_WI', 'COUNTRY_ZIM', 'PLAYING ROLE_Batsman', 'PLAYING ROLE_Bowler', 'PLAYING ROLE_W. Keeper', 'CAPTAINCY EXP_1']

# %%
pvals = list(s)
print(pvals)
# Out:
# [0.10490056300775756, 0.10452389864625707, 0.828465038748317, 0.06995144805557554, 0.7405192506862573, 0.33057150492719367, 0.6162566266912458, 0.5101209414895265, 0.0363441100682403, 0.007061202278855829, 0.33790136372721313, 0.3005898789801068, 0.8152066325802068, 0.6732332708123737, 0.6139605241982333, 0.6044521679304562, 0.5871460364373557, 0.04687188990190799, 0.15871319928083427, 0.7815659102069422, 0.006187800746682825, 0.22288580255403864, 0.2666606170703119, 0.6958965700366722, 0.6579439107634073, 0.921848119587046, 0.9634507275299455, 0.7181351775439592, 0.6158059560018925, 0.9033245876265921, 0.7392765951880749, 0.18784727942388377]

# %%
new = [i for i in zip(impt_vars,pvals)] 
print("List of all variables and their pvalues is",new)
important_vars = [ i[0]  for i in new if i[1] < 0.05]

print("List of influencing variables is",important_vars)
# Out:
# List of all variables and their pvalues is [('const', 0.10490056300775756), ('T-RUNS', 0.10452389864625707), ('T-WKTS', 0.828465038748317), ('ODI-RUNS-S', 0.06995144805557554), ('ODI-SR-B', 0.7405192506862573), ('ODI-WKTS', 0.33057150492719367), ('ODI-SR-BL', 0.6162566266912458), ('RUNS-S', 0.5101209414895265), ('HS', 0.0363441100682403), ('AVE', 0.007061202278855829), ('SR-B', 0.33790136372721313), ('SIXERS', 0.3005898789801068), ('RUNS-C', 0.8152066325802068), ('WKTS', 0.6732332708123737), ('AVE-BL', 0.6139605241982333), ('ECON', 0.6044521679304562), ('SR-BL', 0.5871460364373557), ('AGE_2', 0.04687188990190799), ('AGE_3', 0.15871319928083427), ('COUNTRY_BAN', 0.7815659102069422), ('COUNTRY_ENG', 0.006187800746682825), ('COUNTRY_IND', 0.22288580255403864), ('COUNTRY_NZ', 0.2666606170703119), ('COUNTRY_PAK', 0.6958965700366722), ('COUNTRY_SA', 0.6579439107634073), ('COUNTRY_SL', 0.921848119587046), ('COUNTRY_WI', 0.9634507275299455), ('COUNTRY_ZIM', 0.7181351775439592), ('PLAYING ROL
# ...

# %% [markdown]
# 9.Train a new model with these significant variables.

# %%
train_X = train_X[important_vars]
ipl_mlr_model2 = sm.OLS(train_y, train_X).fit()
ipl_mlr_model2.summary2()
# Out:
# <class 'statsmodels.iolib.summary2.Summary'>
# """
#                         Results: Ordinary least squares
# ...
# Model:                  OLS              Adj. R-squared (uncentered): 0.655
# Dependent Variable:     SOLD PRICE       AIC:                         2977.6511
# Date:                   2021-10-07 04:35 BIC:                         2988.2287
# No. Observations:       104              Log-Likelihood:              -1484.8
# Df Model:               4                F-statistic:                 50.37
# Df Residuals:           100              Prob (F-statistic):          3.75e-23
# R-squared (uncentered): 0.668            Scale:                       1.5330e+11
# ---------------------------------------------------------------------------------
#                 Coef.       Std.Err.      t     P>|t|      [0.025        0.975]
# ---------------------------------------------------------------------------------
# ...

# %% [markdown]
# Following are the inferences from the model generated:
#
# 1.All the variables are statistically significant in predicting the outcome.
#
# 2.The R-Squared has significantly increased from the previous model. From 0.554 to 0.668.
#
# 3.The model can explain 66.8% of the variation in SOLD Price, since R-Squared is 0.668.

# %% [markdown]
# 10.Make Preditions on validation set of this model2.

# %%
new_test_X = test_X[train_X.columns]
pred_y = ipl_mlr_model2.predict(new_test_X)

# %% [markdown]
# 11.Find r2_score and RMSE of this prediction by model2.

# %%
from sklearn.metrics import r2_score, mean_squared_error
import numpy as np
print("The r2_score of the model is", np.abs(r2_score(test_y, pred_y)))
print("The RMSE of the trained model is", np.sqrt(mean_squared_error(test_y, pred_y)))
print("The model parameters are")
print(ipl_mlr_model2.params)
# Out:
# The r2_score of the model is 0.21816020642155887
# The RMSE of the trained model is 407333.11645475996
# The model parameters are
# HS              -2161.200195
# AVE             29837.693625
# AGE_2           19506.052089
# COUNTRY_ENG    347611.006756
# dtype: float64

# %% [markdown]
# # **DECISION_TREE_GINI**

# %% [markdown]
# 1.Load the German Credit card dataset

# %% [markdown]
# 2.Create a Pandas Frame for this file and explore its content

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
df=pd.read_csv("/content/German Credit Data.csv")
df.info()
df.shape
df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 14 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   checkin_acc        1000 non-null   object
#  1   duration           1000 non-null   int64
#  2   credit_history     1000 non-null   object
#  3   amount             1000 non-null   int64
#  4   savings_acc        1000 non-null   object
#  5   present_emp_since  1000 non-null   object
#  6   inst_rate          1000 non-null   int64
#  7   personal_status    1000 non-null   object
#  8   residing_since     1000 non-null   int64
#  9   age                1000 non-null   int64
#  10  inst_plans         1000 non-null   object
#  11  num_credits        1000 non-null   int64
#  12  job                1000 non-null   object
#  13  status             1000 non-null   int64
# dtypes: int64(7), object(7)
# memory usage: 109.5+ KB
# ...

# %% [markdown]
# 3.Print the first five records and first 7 columns

# %%
df.iloc[0:5,0:7]
# Out:
#   checkin_acc  duration credit_history  ...  savings_acc present_emp_since inst_rate
# 0         A11         6            A34  ...          A65               A75         4
# 1         A12        48            A32  ...          A61               A73         2
# 2         A14        12            A34  ...          A61               A74         2
# 3         A11        42            A32  ...          A61               A74         2
# 4         A11        24            A33  ...          A61               A73         3
#
# [5 rows x 7 columns]

# %% [markdown]
# 4.Print the first five records and remaining columns

# %%
df.iloc[0:5,7:15]
# Out:
#   personal_status  residing_since  age inst_plans  num_credits   job  status
# 0             A93               4   67       A143            2  A173       0
# 1             A92               2   22       A143            1  A173       1
# 2             A93               3   49       A143            1  A172       0
# 3             A93               4   45       A143            1  A173       0
# 4             A93               4   53       A143            2  A173       1

# %% [markdown]
# 5.Few of the columns are categorical and are infered as objects. Ex: checkin_acc. Print all unique values of this column

# %%
df['checkin_acc'].unique()
# Out:
# array(['A11', 'A12', 'A14', 'A13'], dtype=object)

# %% [markdown]
# 6.Encode all categorical features using one-hot encoding. A feature with n values is encoded using (n-1) values, retaining the first one (drop_first = True)

# %%
X_features = list(df.columns)
X_features.remove('status')
encoded_df = pd.get_dummies(df[X_features],drop_first=True)
print(list(encoded_df.columns))
# Out:
# ['duration', 'amount', 'inst_rate', 'residing_since', 'age', 'num_credits', 'checkin_acc_A12', 'checkin_acc_A13', 'checkin_acc_A14', 'credit_history_A31', 'credit_history_A32', 'credit_history_A33', 'credit_history_A34', 'savings_acc_A62', 'savings_acc_A63', 'savings_acc_A64', 'savings_acc_A65', 'present_emp_since_A72', 'present_emp_since_A73', 'present_emp_since_A74', 'present_emp_since_A75', 'personal_status_A92', 'personal_status_A93', 'personal_status_A94', 'inst_plans_A142', 'inst_plans_A143', 'job_A172', 'job_A173', 'job_A174']

# %% [markdown]
# 7.Make independent features of the encoded frame as X and column 'status' as dependent feature.

# %%
X=encoded_df
Y=df['status']

# %% [markdown]
# 8.Divide data into 70% training and 30% as testing.

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,Y,test_size=0.3,random_state=42)

# %% [markdown]
# 9.Train a decision tree model using Gini index and depth of 3

# %%
from sklearn.tree import DecisionTreeClassifier
clf = DecisionTreeClassifier(criterion = 'gini',max_depth=3)
clf.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier(max_depth=3)

# %% [markdown]
# 10.
# Make predictions on test/validation data

# %%
pred_y = clf.predict(X_test)

# %% [markdown]
# 11.Print the confusion matrix, accuracy and AUC score of this model on test set

# %%
from sklearn import metrics
print("Confusion Matrix is\n",metrics.confusion_matrix(pred_y,y_test))
print("Accuracy is",metrics.accuracy_score(pred_y,y_test))
print("AUC Score is",metrics.roc_auc_score(pred_y,y_test))
# Out:
# Confusion Matrix is
#  [[198  71]
#  [ 11  20]]
# Accuracy is 0.7266666666666667
# AUC Score is 0.6906103849382419

# %% [markdown]
# 12.Visualize the tree using grapghviz and pydotplus libraries

# %%
from sklearn.tree import export_graphviz
import pydotplus as pdot
from IPython.display import Image

export_graphviz(clf,out_file = "tree.odt",feature_names = X_train.columns,filled = True)
graph = pdot.graphviz.graph_from_dot_file("tree.odt")
graph.write_jpg("tree.png")
Image(filename="tree.png")

# %% [markdown]
# # **Gradient_Descent**

# %% [markdown]
# # **EX1**

# %% [markdown]
# 1.Implement a regression model given input x = [1,2,3,4,5] and output y = [5,7,9,11,13]. Using Gradient descent find the optimum values of m and b that minimise the loss function (MSE). By manual calculations, we easy identify that y = 2x + 3 should be the regression line with m = 2 and b = 3. Lets try to get the same using Gradient Descent.

# %%
import numpy as np
def gradient_descent(x,y):
  m_curr = b_curr = 0
  iterations = 1000
  learning_rate = 0.001
  n = len(x)
  for i in range(iterations):
    y_predicted = m_curr * x + b_curr
    cost = (1/n)*sum([val**2 for val in (y-y_predicted)])
    md = -(2/n)*sum(x*(y-y_predicted))
    bd = -(2/n)*sum(y-y_predicted)
    m_curr = m_curr - learning_rate*md
    b_curr = b_curr - learning_rate*bd
    print("m is {0}, b is {1},cost is {2} iteration is {3}".format(m_curr,b_curr,cost,i))

x=np.array([1,2,3,4,5])
y=np.array([5,7,9,11,13])
gradient_descent(x,y)
# Out:
# m is 0.062, b is 0.018000000000000002,cost is 89.0 iteration is 0
# m is 0.122528, b is 0.035592000000000006,cost is 84.881304 iteration is 1
# m is 0.181618832, b is 0.052785648000000004,cost is 80.955185108544 iteration is 2
# m is 0.239306503808, b is 0.069590363712,cost is 77.21263768455901 iteration is 3
# m is 0.29562421854195203, b is 0.086015343961728,cost is 73.64507722605434 iteration is 4
# m is 0.35060439367025875, b is 0.10206956796255283,cost is 70.2443206760065 iteration is 5
# m is 0.40427867960173774, b is 0.11776180246460617,cost is 67.00256764921804 iteration is 6
# m is 0.4566779778357119, b is 0.13310060678206653,cost is 63.912382537082294 iteration is 7
# m is 0.5078324586826338, b is 0.14809433770148814,cost is 60.966677449199324 iteration is 8
# m is 0.5577715785654069, b is 0.16275115427398937,cost is 58.15869595270883 iteration is 9
# m is 0.606524096911324, b is 0.17707902249404894,cost is 55.481997572035766 iteration is 10
# ...

# %% [markdown]
# 2.We can observe cost is decreasing in each iteraion. Increase the iterations and check whether cost is decreasing further

# %%
import numpy as np
def gradient_descent(x,y):
  m_curr = b_curr=0
  iterations=10000
  learning_rate=0.001
  n=len(x)
  for i in range(iterations):
    y_predicted = m_curr * x + b_curr
    cost = (1/n) * sum([val ** 2 for val in (y - y_predicted)])
    md = -(2/n) * sum(x * (y - y_predicted))
    bd = - (2/n) * sum(y - y_predicted)
    m_curr = m_curr - learning_rate * md
    b_curr = b_curr - learning_rate * bd
    print("m is {0}, b is {1}, cost is {2} iteration is {3}".format(m_curr, b_curr, cost, i))

x = np.array([1,2,3,4,5])
y = np.array([5,7,9,11,13])
gradient_descent(x,y)
# Out:
# Streaming output truncated to the last 5000 lines.
# m is 2.1159781987036776, b is 2.5812819029965524, cost is 0.03193377887660422 iteration is 5000
# m is 2.1159389869142173, b is 2.581423469998337, cost is 0.031912189147685885 iteration is 5001
# m is 2.1158997883821145, b is 2.5815649891368553, cost is 0.03189061401511098 iteration is 5002
# m is 2.115860603102887, b is 2.581706460428289, cost is 0.031869053469010554 iteration is 5003
# m is 2.1158214310720536, b is 2.581847883888815, cost is 0.03184750749952369 iteration is 5004
# m is 2.1157822722851356, b is 2.581989259534605, cost is 0.03182597609679516 iteration is 5005
# m is 2.115743126737655, b is 2.5821305873818248, cost is 0.031804459250976906 iteration is 5006
# m is 2.115703994425136, b is 2.5822718674466354, cost is 0.03178295695222696 iteration is 5007
# m is 2.115664875343103, b is 2.5824130997451915, cost is 0.03176146919071039 iteration is 5008
# ...

# %% [markdown]
# Yes, cost is decreasing and we reached the values of m = 2 and b = 3 which we got in the manual working.

# %% [markdown]
# 3.Try with bigger steps, ie, learning rate = 0.1 and iterations = 10

# %%
import numpy as np
def gradient_descent(x,y):
  m_curr = b_curr = 0
  iterations = 10
  learning_rate = 0.1
  n = len(x)
  for i in range(iterations):
    y_predicted = m_curr * x + b_curr
    cost = (1/n) * sum([val ** 2 for val in (y - y_predicted)])
    md = -(2/n) * sum(x * (y - y_predicted))
    bd = - (2/n) * sum(y - y_predicted)
    m_curr = m_curr - learning_rate * md
    b_curr = b_curr - learning_rate * bd
    print("m is {0}, b is {1}, cost is {2} iteration is {3}".format(m_curr, b_curr, cost, i))

x = np.array([1,2,3,4,5])
y = np.array([5,7,9,11,13])
gradient_descent(x,y)
# Out:
# m is 6.2, b is 1.8, cost is 89.0 iteration is 0
# m is -2.320000000000001, b is -0.4800000000000002, cost is 165.24 iteration is 1
# m is 9.272000000000002, b is 2.8080000000000007, cost is 307.59840000000014 iteration is 2
# m is -6.611200000000007, b is -1.5168000000000017, cost is 573.3613440000004 iteration is 3
# m is 15.043520000000012, b is 4.5532800000000035, cost is 1069.4523110400019 iteration is 4
# m is -14.584192000000016, b is -3.5834880000000053, cost is 1995.4416651264037 iteration is 5
# m is 25.851123200000032, b is 7.6837248000000065, cost is 3723.822955597831 iteration is 6
# m is -29.431582720000037, b is -7.563694080000013, cost is 6949.846718357686 iteration is 7
# m is 46.056115712000064, b is 13.407994368000011, cost is 12971.181693567853 iteration is 8
# m is -57.11213547520009, b is -15.10727393280003, cost is 24209.895819923568 iteration is 9

# %% [markdown]
# We can observe that the cost is increasing. This approach is wrong, since we have taken bigger steps with learning rate = 0.1. Usually learning rate is a smaller value like 0.0001

# %% [markdown]
# 4.Set iterations = 10000 and learning rate = 0.08 and check whether cost remains same.

# %%
import numpy as np
def gradient_descent(x,y):
  m_curr = b_curr = 0
  iterations = 10000
  learning_rate = 0.08
  n = len(x)
  for i in range(iterations):
    y_predicted = m_curr * x + b_curr
    cost = (1/n) * sum([val ** 2 for val in (y - y_predicted)])
    md = -(2/n) * sum(x * (y - y_predicted))
    bd = - (2/n) * sum(y - y_predicted)
    m_curr = m_curr - learning_rate * md
    b_curr = b_curr - learning_rate * bd
    print("m is {0}, b is {1}, cost is {2} iteration is {3}".format(m_curr, b_curr, cost, i))

x = np.array([1,2,3,4,5])
y = np.array([5,7,9,11,13])
gradient_descent(x,y)
# Out:
# Streaming output truncated to the last 5000 lines.
# m is 2.000000000000001, b is 2.9999999999999947, cost is 1.0255191767873153e-29 iteration is 5000
# m is 2.000000000000002, b is 2.999999999999995, cost is 1.0255191767873153e-29 iteration is 5001
# m is 2.000000000000001, b is 2.9999999999999947, cost is 1.0255191767873153e-29 iteration is 5002
# m is 2.000000000000002, b is 2.999999999999995, cost is 1.0255191767873153e-29 iteration is 5003
# m is 2.000000000000001, b is 2.9999999999999947, cost is 1.0255191767873153e-29 iteration is 5004
# m is 2.000000000000002, b is 2.999999999999995, cost is 1.0255191767873153e-29 iteration is 5005
# m is 2.000000000000001, b is 2.9999999999999947, cost is 1.0255191767873153e-29 iteration is 5006
# m is 2.000000000000002, b is 2.999999999999995, cost is 1.0255191767873153e-29 iteration is 5007
# m is 2.000000000000001, b is 2.9999999999999947, cost is 1.0255191767873153e-29 iteration is 5008
# ...

# %% [markdown]
# Yes, after a certain iteration, cost remains the same.

# %% [markdown]
# 5.Alternatively, we can check whether the cost between two iterations is within a tolerance value. Hence find the number of iterations needed by the Gradient Descent to converge at an optimum value for m and b. This is done using the math.isclose() with a tolerance of 1e-09.

# %%
import numpy as np
import math
def gradient_descent(x,y):
  m_curr = b_curr = 0
  iterations = 10000
  learning_rate = 0.08
  n = len(x)
  
  for i in range(iterations):
    y_predicted = m_curr * x + b_curr
    cost = (1/n) * sum([val ** 2 for val in (y - y_predicted)])
    md = -(2/n) * sum(x * (y - y_predicted))
    bd = - (2/n) * sum(y - y_predicted)
    m_curr = m_curr - learning_rate * md
    b_curr = b_curr - learning_rate * bd
    y_predicted = m_curr * x + b_curr
    new_cost = (1/n) * sum([val ** 2 for val in (y - y_predicted)])
    if math.isclose(cost,new_cost,rel_tol = 1e-09):
      print("m is {0}, b is {1}, cost is {2} iteration is {3}".format(m_curr, b_curr, new_cost, i))
      break
    else:
      print("m is {0}, b is {1}, cost is {2} iteration is {3}".format(m_curr, b_curr, new_cost, i))

x = np.array([1,2,3,4,5])
y = np.array([5,7,9,11,13])
gradient_descent(x,y)
# Out:
# m is 4.96, b is 1.44, cost is 71.10560000000002 iteration is 0
# m is 0.4991999999999983, b is 0.26879999999999993, cost is 56.8297702400001 iteration is 1
# m is 4.451584000000002, b is 1.426176000000001, cost is 45.43965675929613 iteration is 2
# m is 0.892231679999997, b is 0.5012275199999995, cost is 36.35088701894832 iteration is 3
# m is 4.041314713600002, b is 1.432759910400001, cost is 29.097483330142282 iteration is 4
# m is 1.2008760606719973, b is 0.7036872622079998, cost is 23.307872849944438 iteration is 5
# m is 3.7095643080294423, b is 1.4546767911321612, cost is 18.685758762535738 iteration is 6
# m is 1.4424862661541864, b is 0.881337636696883, cost is 14.994867596913156 iteration is 7
# m is 3.4406683721083144, b is 1.4879302070713722, cost is 12.046787238456794 iteration is 8
# m is 1.6308855378034224, b is 1.0383405553279617, cost is 9.691269350698109 iteration is 9
# m is 3.2221235247119777, b is 1.5293810083298451, cost is 7.8084968312098315 iteration is 10
# ...

# %% [markdown]
# Hence cost of Iterations 1210 and 1211 remains same. It means cost will be same henceforth. So, it takes 1210 number of iterations for the Gradient Descent to converge at an optimum value for m and b.

# %% [markdown]
# # **EX-2-with SLR**

# %% [markdown]
# Simple Linear Regression Using Gradient Descent method. Develop a regression model to predict Salary based on Percentage in Grade 10.

# %% [markdown]
# 1.Import the MBA Salary dataset. Print the shape, description and first five records.

# %%
import pandas as pd
df = pd.read_csv("/content/MBA Salary.csv")
print(df.shape)
print(df.info)
print(df.head(2))
# Out:
# (50, 3)
# <bound method DataFrame.info of     S. No.  Percentage in Grade 10  Salary
# 0        1                   62.00  270000
# 1        2                   76.33  200000
# 2        3                   72.00  240000
# 3        4                   60.00  250000
# 4        5                   61.00  180000
# 5        6                   55.00  300000
# 6        7                   70.00  260000
# 7        8                   68.00  235000
# 8        9                   82.80  425000
# 9       10                   59.00  240000
# 10      11                   58.00  250000
# 11      12                   60.00  180000
# 12      13                   66.00  428000
# 13      14                   83.00  450000
# 14      15                   68.00  300000
# 15      16                   37.33  240000
# 16      17                   79.00  252000
# 17      18                   68.40  280000
# 18      19                   70.00  231000
# 19      20                   59.00  224000
# ...

# %% [markdown]
# 2. Creating feature set X and the outcome variable Y.

# %%
import numpy as np
X = np.array(df['Percentage in Grade 10'])
Y = np.array(df['Salary'])

# %% [markdown]
# 3. Split dataset into training and validation sets. Use 80% for training and 20% for validating

# %%
from sklearn.model_selection import train_test_split
train_X,test_X,train_y,test_y = train_test_split(X,Y,train_size=0.8,random_state=100)

# %% [markdown]
# 4.USing Gradient Descent with a learning rate of 0.0001 for 100 iterations, find the optimal values of the regression coefficients m and b.

# %%
import numpy as np
def gradient_descent(x,y):
  m_curr = b_curr = 0
  iterations = 100
  learning_rate = 0.0001
  n = len(x)
  for i in range(iterations):
    y_predicted = m_curr * x + b_curr
    cost = (1/n)*sum([val ** 2 for val in (y-y_predicted)])
    md = -(2/n)*sum(x*(y-y_predicted))
    bd = -(2/n)*sum(y-y_predicted)
    m_curr = m_curr-learning_rate*md
    b_curr = b_curr-learning_rate*bd
    print("m is{0}, b is {1},cost is {2} iteration is {3}".format(m_curr,b_curr,cost,i))
    return(m_curr,b_curr)
train_X = np.array(train_X)
train_y = np.array(train_y)
#print(train_X[0:4])
optimal_params = gradient_descent(train_X, train_y)
print("The best values of slope and intercept are", optimal_params)
# Out:
# m is3337.264, b is 51.38,cost is 72032450000.0 iteration is 0
# The best values of slope and intercept are (3337.264, 51.38)

# %% [markdown]
# 5.Making predictions on validation set and report - R-Squared and RMSE

# %%
import numpy as np
from sklearn.metrics import r2_score, mean_squared_error
test_X = np.array(test_X)
pred_y = optimal_params[0]*test_X + optimal_params[1]
#print(pred_y)
print('R2 Score =',np.abs(r2_score(test_y,pred_y)))
print('RMSE = ', np.sqrt(mean_squared_error(test_y,pred_y)))
# Out:
# R2 Score = 0.5723084278027168
# RMSE =  85646.1856992674

# %% [markdown]
# # **Hyperparameter**

# %% [markdown]
# **Hyperparameter Tuning for kNN for Predicting Heart Disease**

# %% [markdown]
# 1.Import "heart.csv".

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-fb52f51d-ca46-4699-8202-08c4a14eb69d" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-fb52f51d-ca46-4699-8202-08c4a14eb69d">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving heart.csv to heart.csv

# %% [markdown]
# 2.Import Library

# %%
import pandas as pd
import seaborn as sns
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import classification_report
from sklearn.model_selection import train_test_split
from sklearn.metrics import roc_auc_score
from sklearn.model_selection import GridSearchCV

# %% [markdown]
# 3.Load the Dataset into a frame

# %%
df = pd.read_csv("/content/heart.csv")

# %% [markdown]
# 4.Print the description, dimensions and first five records of the frame.

# %%
print(df.info())
print(df.shape)
print(df.head())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 303 entries, 0 to 302
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       303 non-null    int64
#  1   sex       303 non-null    int64
#  2   cp        303 non-null    int64
#  3   trestbps  303 non-null    int64
#  4   chol      303 non-null    int64
#  5   fbs       303 non-null    int64
#  6   restecg   303 non-null    int64
#  7   thalach   303 non-null    int64
#  8   exang     303 non-null    int64
#  9   oldpeak   303 non-null    float64
#  10  slope     303 non-null    int64
#  11  ca        303 non-null    int64
#  12  thal      303 non-null    int64
#  13  target    303 non-null    int64
# dtypes: float64(1), int64(13)
# memory usage: 33.3 KB
# None
# (303, 14)
#    age  sex  cp  trestbps  chol  fbs  ...  exang  oldpeak  slope  ca  thal  target
# 0   63    1   3       145   233    1  ...      0      2.3      0   0     1       1
# ...

# %% [markdown]
# 5.Check whether the data has any missing value in any column.

# %%
df.isnull().sum()
# Out:
# age         0
# sex         0
# cp          0
# trestbps    0
# chol        0
# fbs         0
# restecg     0
# thalach     0
# exang       0
# oldpeak     0
# slope       0
# ca          0
# thal        0
# target      0
# dtype: int64

# %% [markdown]
# 6.Check whether the data has balanced class distribution. Class target = 0 indicates "Heart Disease" and target = 1 indicates "No Heart Disease".

# %%
sns.countplot(df['target'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# 7.Create input features X, target Y, classifier object, train-test-split using 80-20% split

# %%
x = df.drop(columns=['target'])
y = df['target']
knn = KNeighborsClassifier()
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=4)

# %% [markdown]
# 8.Train model

# %%
#Training the model
knn.fit(x_train, y_train)
# Out:
# KNeighborsClassifier()

# %% [markdown]
# 9.Validate model on test set

# %%
y_pred = knn.predict(x_test)

# %% [markdown]
# 10.Print Classification Report on test data

# %%
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.48      0.52      0.50        25
#            1       0.65      0.61      0.63        36
#
#     accuracy                           0.57        61
#    macro avg       0.56      0.57      0.56        61
# weighted avg       0.58      0.57      0.58        61

# %% [markdown]
# 11.Print AUC score on test data

# %%
roc_auc_score(y_test,y_pred)
# Out:
# 0.5655555555555556

# %% [markdown]
# The performance of the model is vey poor. Hence hyperparameters of kNN to be tuned using GridSearchCV.

# %% [markdown]
# 12.Hyperparameter tuning using GridSearchCV. Set the parameters a)leaf-size= 1 to 15, b)n_neighbors = 1 to 10 and c) distance metric, p = 1, 2. When p =1 its Manhattan and p = 2 its Euclidean distance. GridSearchCV uses CV to search for the optimal values of the hyperparameters. It accepts the hyperparameters as a dictionary.

# %%
leaf_size = list(range(1,15))
n_neighbors = list(range(1,10))
p=[1,2]
hyperparameters = dict(leaf_size=leaf_size,n_neighbors=n_neighbors,p=p)

# %% [markdown]
# 13.Train a new kNN model using GridSearchCV.

# %%
knn_2 = KNeighborsClassifier()
clf = GridSearchCV(knn_2,hyperparameters,cv=10,scoring='roc_auc')
best_model = clf.fit(x,y)

# %% [markdown]
# 14.Print the best values of the hyperparamters.

# %%
#Nilai hyperpaameters terbaik
print('Best leaf_size:', best_model.best_estimator_.get_params()['leaf_size'])
print('Best p:', best_model.best_estimator_.get_params()['p'])
print('Best n_neighbors:', best_model.best_estimator_.get_params()['n_neighbors'])
print('Best Score:', best_model.best_score_)
# Out:
# Best leaf_size: 9
# Best p: 1
# Best n_neighbors: 7
# Best Score: 0.7483536683904332

# %% [markdown]
# 15.Validate the model on test data

# %%
y_pred = best_model.predict(x_test)

# %% [markdown]
# 16.Print classification report and AUC score o fthe model on test data

# %%
print(classification_report(y_test,y_pred))
print("AUC SCORE is ",roc_auc_score(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.72      0.72      0.72        25
#            1       0.81      0.81      0.81        36
#
#     accuracy                           0.77        61
#    macro avg       0.76      0.76      0.76        61
# weighted avg       0.77      0.77      0.77        61
#
# AUC SCORE is  0.7627777777777778

# %% [markdown]
# # **BAGGING AND CROSS VALIDATION**

# %% [markdown]
# 1 : Implement the Bagging based Ensemble Model using CART (Classification and Regression Trees) as base learners. No. of base learners = 100. Use cross validation as the model estimation method.

# %%
import pandas as pd
from sklearn import model_selection
from sklearn.ensemble import BaggingClassifier
from sklearn.tree import DecisionTreeClassifier
url='https://raw.githubusercontent.com/jbrownlee/Datasets/master/pima-indians-diabetes.data.csv'
names=['preg','plas','pres','skin','test','mass','pedi','age','class']
df=pd.read_csv(url,names=names)
df.shape
# Out:
# (768, 9)

# %%
array=df.values
X=array[:,0:8]
Y=array[:,8] #TaRgEt VaRiAbLe
Kfold=model_selection.KFold(n_splits=10,random_state=None)
cart=DecisionTreeClassifier()
num_trees=100
model=BaggingClassifier(base_estimator=cart,n_estimators=num_trees,random_state=7)
results=model_selection.cross_val_score(model,X,Y,cv=Kfold)
average_accuracy=sum(results)/len(results)
print("Average Accuracy is ",average_accuracy*100)
# Out:
# Average Accuracy is  77.20437457279563

# %% [markdown]
# 2 : Implement the AdaBoost Ensemble model for classification using 10 base learners and cross validation.

# %%
import pandas as pd
from sklearn import model_selection
from sklearn.ensemble import AdaBoostClassifier
from sklearn.tree import DecisionTreeClassifier
url='https://raw.githubusercontent.com/jbrownlee/Datasets/master/pima-indians-diabetes.data.csv'
names=['preg','plas','pres','skin','test','mass','pedi','age','class']
df=pd.read_csv(url,names=names)
df.shape
# Out:
# (768, 9)

# %%
array=df.values
X=array[:,0:8]
Y=array[:,8] #target
Kfold=model_selection.KFold(n_splits=10,random_state=None)
num_trees=10 #10 base learners
model=AdaBoostClassifier(n_estimators=num_trees,random_state=7)
results=model_selection.cross_val_score(model,X,Y,cv=Kfold)
average_accuracy=sum(results)/len(results)
print("Average Accuracy is ", average_accuracy*100)
# Out:
# Average Accuracy is  75.25974025974025

# %% [markdown]
# 3: (Same as Question 1) Implement the Bagging based Ensemble Model using k-Nearest Neighbor Classifier as base learners. No. of base learners = 100. Use cross validation as the model estimation method.

# %%
import pandas as pd
from sklearn import model_selection
from sklearn.ensemble import BaggingClassifier
from sklearn.neighbors import KNeighborsClassifier
url='https://raw.githubusercontent.com/jbrownlee/Datasets/master/pima-indians-diabetes.data.csv'
names=['preg','plas','pres','skin','test','mass','pedi','age','class']
df=pd.read_csv(url,names=names)
df.shape
# Out:
# (768, 9)

# %%
array=df.values
X=array[:,0:8]
Y=array[:,8] #target
Kfold=model_selection.KFold(n_splits=10,random_state=None)
knn=KNeighborsClassifier()
num_learners=100
model=BaggingClassifier(base_estimator=knn,n_estimators=num_learners,random_state=7)
results=model_selection.cross_val_score(model,X,Y,cv=Kfold)
average_accuracy=sum(results)/len(results)
print("Average Accuracy is ", average_accuracy*100)
# Out:
# Average Accuracy is  73.56459330143541

# %% [markdown]
# # **K_MEANS CLUSTERING**

# %% [markdown]
# 1.Create a data frame and visualize the natural groupings in the dataset

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
df=pd.read_csv("/content/Income Data.csv")
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 300 entries, 0 to 299
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   income  300 non-null    float64
#  1   age     300 non-null    float64
# dtypes: float64(2)
# memory usage: 4.8 KB

# %%
df.head()
# Out:
#     income    age
# 0  41100.0  48.75
# 1  54100.0  28.10
# 2  47800.0  46.75
# 3  19100.0  40.25
# 4  18200.0  35.80

# %%
df.shape
# Out:
# (300, 2)

# %%
sns.set_style('whitegrid')
sns.lmplot("age","income",data=df,fit_reg=False,size=4)#lm - linear model plot(simple regression plot)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /usr/local/lib/python3.7/dist-packages/seaborn/regression.py:581: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
plt.scatter(df['age'],df['income'],c = 'red')
plt.title('Scatter plot Age Versus Income')
plt.xlabel('Age')
plt.ylabel('Income')
# Out:
# Text(0, 0.5, 'Income')

# %% [markdown]
# 2.The above groupings are mostly segmented using income, since it has a huge range. Scale of age is 0 to 60 and income is from 0 to 50000. Hence Euclidean distance will always be dominated by income and not age. Hence all features need to be normalised to a uniform scale before clustering.

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
scaled_df = scaler.fit_transform(df[["age","income"]]) #modeling..[null to mean values]
scaled_df[0:5]
# Out:
# array([[ 1.3701637 ,  0.09718548],
#        [-1.3791283 ,  0.90602749],
#        [ 1.10388844,  0.51405021],
#        [ 0.23849387, -1.27162408],
#        [-0.35396857, -1.32762083]])

# %% [markdown]
# 3.PLotting customers with their segments(clusters)

# %%
from sklearn.cluster import KMeans
clusters = KMeans(3)
clusters.fit(scaled_df)
df["ClusterId"]=clusters.labels_
markers=["+","*","^"]
sns.lmplot(x="age",y="income",data=df,hue="ClusterId",fit_reg=False,markers=markers,size=4)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/regression.py:581: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %% [markdown]
# 4.Print the cluster centers using the original dataframe. Cluster centres explain the characteristics of the cluster and helps us to interpret the clusters. Print the cluster centres to understand the average age and income of each cluster.

# %%
clusters=KMeans(3)
clusters.fit(df)
df['new cluster id'] = clusters.labels_
df.groupby('new cluster id')['age','income'].agg(['mean','std']).reset_index()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:4: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   after removing the cwd from sys.path.
#   new cluster id        age                  income
#                        mean       std          mean          std
# 0              0  31.700435  6.122122  54675.652174  2362.224320
# 1              1  39.174479  3.626068  18144.791667  6745.241906
# 2              2  46.419101  2.289620  43053.932584  3613.769632

# %% [markdown]
# 5.So Cluster 0 has a mean age of 39 and income of 18K. Low age and low income. CLuster 1 has a mean age of 37 and income of 54K. Mid age and high income. CLuster 2 has a mean age of 46 and income of 43K. High age and medium income. The actual age and income of a customer within a cluster will vary from the cluster centers and is called the cluster variance. This is given by WCSS - within cluster sum of squares.

# %% [markdown]
# 6.Find the optimum number of clusters that may exist using Elbow Method. Try with number of clusters from 1 to 10. In each case print the total variance using "inertia" parameter of the clusters.

# %%
cluster_range=range(1,10)
cluster_errors=[]
for num_clusters in cluster_range:
  clusters=KMeans(num_clusters)
  clusters.fit(scaled_df)
  cluster_errors.append(clusters.inertia_)
plt.figure(figsize=(6,4))
plt.plot(cluster_range,cluster_errors,marker="*")
plt.xlabel("No.of clusters ")
plt.ylabel("Sum of Squarred Error")
# Out:
# Text(0, 0.5, 'Sum of Squarred Error')

# %%
from sklearn.cluster import KMeans
wcss = [] 
for i in range(1, 11): 
    kmeans = KMeans(n_clusters = i, init = 'k-means++', random_state = 42)
    kmeans.fit(df) 
    wcss.append(kmeans.inertia_)

# %% [markdown]
# The figure indicates the elbow point is 3, this means there might exist three clusters in the data set.

# %% [markdown]
# # **Agglomerative_Clustering**

# %% [markdown]
# 1.Import dataset

# %%
import pandas as pd
df=pd.read_csv("/content/beer.csv")
print(df.head())
print(df.columns)
print(df.shape)
# Out:
#           name  calories  sodium  alcohol  cost
# 0    Budweiser       144      15      4.7  0.43
# 1      Schlitz       151      19      4.9  0.43
# 2    Lowenbrau       157      15      0.9  0.48
# 3  Kronenbourg       170       7      5.2  0.73
# 4     Heineken       152      11      5.0  0.77
# Index(['name', 'calories', 'sodium', 'alcohol', 'cost'], dtype='object')
# (20, 5)

# %% [markdown]
# 2.Normalize the numerical features

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
scaled_df=scaler.fit_transform(df[['calories','sodium','alcohol','cost']])
scaled_df
# Out:
# array([[ 0.38791334,  0.00779468,  0.43380786, -0.45682969],
#        [ 0.6250656 ,  0.63136906,  0.62241997, -0.45682969],
#        [ 0.82833896,  0.00779468, -3.14982226, -0.10269815],
#        [ 1.26876459, -1.23935408,  0.90533814,  1.66795955],
#        [ 0.65894449, -0.6157797 ,  0.71672602,  1.95126478],
#        [ 0.42179223,  1.25494344,  0.3395018 , -1.5192243 ],
#        [ 1.43815906,  1.41083704,  1.1882563 , -0.66930861],
#        [ 0.55730781,  1.87851782,  0.43380786, -0.52765599],
#        [-1.1366369 , -0.7716733 ,  0.05658363, -0.45682969],
#        [-0.66233238, -1.08346049, -0.5092527 , -0.66930861],
#        [ 0.25239776,  0.47547547,  0.3395018 , -0.38600338],
#        [-1.03500022,  0.00779468, -0.13202848, -0.24435076],
#        [ 0.08300329, -0.6157797 , -0.03772242,  0.03895447],
#        [ 0.59118671,  0.63136906,  0.43380786,  1.88043848],
#        [ 0.55730781, -1.39524768,  0.71672602,  2.0929174 ],
# ...

# %% [markdown]
# 3.Implement kmeans clustering with k=3.

# %%
from sklearn.cluster import KMeans
k=3
clusters=KMeans(k,random_state=42)
clusters.fit(scaled_df)
df['clusterid']=clusters.labels_

# %% [markdown]
# 4.Interpret the clusters obtained

# %%
df[df["clusterid"]==0 ]
# Out:
#                     name  calories  sodium  alcohol  cost  clusterid
# 0              Budweiser       144      15      4.7  0.43          0
# 1                Schlitz       151      19      4.9  0.43          0
# 5          Old_Milwaukee       145      23      4.6  0.28          0
# 6             Augsberger       175      24      5.5  0.40          0
# 7   Srohs_Bohemian_Style       149      27      4.7  0.42          0
# 10                 Coors       140      18      4.6  0.44          0
# 16                 Hamms       139      19      4.4  0.43          0
# 17   Heilemans_Old_Style       144      24      4.9  0.43          0

# %% [markdown]
# This cluster has a all light beers with low calories and sodium content.This might be addressing the customer segment who wish to drink but are also calorie conscious.

# %%
df[df['clusterid']==1]
# Out:
#                    name  calories  sodium  alcohol  cost  clusterid
# 2             Lowenbrau       157      15      0.9  0.48          1
# 8           Miller_Lite        99      10      4.3  0.43          1
# 9       Budweiser_Light       113       8      3.7  0.40          1
# 11          Coors_Light       102      15      4.1  0.46          1
# 12       Michelob_Light       135      11      4.2  0.50          1
# 15    Pabst_Extra_Light        68      15      2.3  0.38          1
# 18  Olympia_Goled_Light        72       6      2.9  0.46          1
# 19        Schlitz_Light        97       7      4.2  0.47          1

# %% [markdown]
# This cluster has beers with medium alcohol content and medium cost.

# %%
df[df['clusterid']==2]
# Out:
#            name  calories  sodium  alcohol  cost  clusterid
# 3   Kronenbourg       170       7      5.2  0.73          2
# 4      Heineken       152      11      5.0  0.77          2
# 13        Becks       150      19      4.7  0.76          2
# 14        Kirin       149       6      5.0  0.79          2

# %% [markdown]
# Ths cluster has expensive beers with high alcohol content.Sodium content is low.Costs are high,so the target customers might be brand sensitive.

# %% [markdown]
# 5.Implement Agglomerative Clustering with default parameters.Compare these clusters with those of KMeans

# %%
from sklearn.cluster import AgglomerativeClustering
n_clusters=AgglomerativeClustering(3)

# %%
n_clusters.fit(scaled_df)
df['n_clusterid']=n_clusters.labels_

# %%
df[df['clusterid']==0]
# Out:
#                     name  calories  sodium  ...  cost  clusterid  n_clusterid
# 0              Budweiser       144      15  ...  0.43          0            1
# 1                Schlitz       151      19  ...  0.43          0            1
# 5          Old_Milwaukee       145      23  ...  0.28          0            1
# 6             Augsberger       175      24  ...  0.40          0            1
# 7   Srohs_Bohemian_Style       149      27  ...  0.42          0            1
# 10                 Coors       140      18  ...  0.44          0            1
# 16                 Hamms       139      19  ...  0.43          0            1
# 17   Heilemans_Old_Style       144      24  ...  0.43          0            1
#
# [8 rows x 7 columns]

# %%
df[df['clusterid']==1]
# Out:
#                    name  calories  sodium  ...  cost  clusterid  n_clusterid
# 2             Lowenbrau       157      15  ...  0.48          1            0
# 8           Miller_Lite        99      10  ...  0.43          1            0
# 9       Budweiser_Light       113       8  ...  0.40          1            0
# 11          Coors_Light       102      15  ...  0.46          1            0
# 12       Michelob_Light       135      11  ...  0.50          1            0
# 15    Pabst_Extra_Light        68      15  ...  0.38          1            0
# 18  Olympia_Goled_Light        72       6  ...  0.46          1            0
# 19        Schlitz_Light        97       7  ...  0.47          1            0
#
# [8 rows x 7 columns]

# %%
df[df['clusterid']==2]
# Out:
#            name  calories  sodium  alcohol  cost  clusterid  n_clusterid
# 3   Kronenbourg       170       7      5.2  0.73          2            2
# 4      Heineken       152      11      5.0  0.77          2            2
# 13        Becks       150      19      4.7  0.76          2            2
# 14        Kirin       149       6      5.0  0.79          2            2

# %% [markdown]
# Clusters obtained by both k-means and Agglomerative clustering is same.Only the cluster-id is different.

# %% [markdown]
# 6.Implement Agglomerative single linkage clustering.

# %%
n_clusters_single=AgglomerativeClustering(3,linkage="single")
n_clusters_single.fit(scaled_df)
df['n_single_cluster_id']=n_clusters_single.labels_

# %%
df[df['n_single_cluster_id']==0]
# Out:
#                     name  calories  ...  n_clusterid  n_single_cluster_id
# 0              Budweiser       144  ...            1                    0
# 1                Schlitz       151  ...            1                    0
# 5          Old_Milwaukee       145  ...            1                    0
# 6             Augsberger       175  ...            1                    0
# 7   Srohs_Bohemian_Style       149  ...            1                    0
# 8            Miller_Lite        99  ...            0                    0
# 9        Budweiser_Light       113  ...            0                    0
# 10                 Coors       140  ...            1                    0
# 11           Coors_Light       102  ...            0                    0
# 12        Michelob_Light       135  ...            0                    0
# 15     Pabst_Extra_Light        68  ...            0                    0
# 16                 Hamms       139  ...            1                    0
# ...

# %% [markdown]
# # **TIME SERIES FORECASTING**

# %% [markdown]
# Implement moving average technique using the demand dataset "wsb.csv". This is a demand dataset for "Kesh" a shampoo brand which is sold in 100ml bottles by "We Sell Beauty (WSB)", a manufacturer and distributor of health and beauty products.

# %% [markdown]
# 1. Import "wsb.csv"

# %%
from google.colab import files
upload=files.upload()
# Out:
#      <input type="file" id="files-f206406f-6026-47e3-8f24-9c0d1141e8ad" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-f206406f-6026-47e3-8f24-9c0d1141e8ad">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving wsb.csv to wsb.csv

# %% [markdown]
# 2. Create a frame

# %%
import pandas as pd
df=pd.read_csv("/content/wsb.csv")
print("Data set read successfully")
# Out:
# Data set read successfully

# %%
df.head()
# Out:
#    Month  Sale Quantity  Promotion Expenses  Competition Promotion
# 0      1        3002666                 105                      1
# 1      2        4401553                 145                      0
# 2      3        3205279                 118                      1
# 3      4        4245349                 130                      0
# 4      5        3001940                  98                      1

# %% [markdown]
# 3. Visualize "Sales Quantity" over "Month"

# %%
import matplotlib.pyplot as plt
import seaborn as sns
plt.figure(figsize=(12,5))
sns.set_style("darkgrid")
plt.xlabel('Months',fontsize=20)
plt.ylabel("Sale Quantity",fontsize=20)
plt.title("Sales Quantity vs Month",fontsize=20)
plt.plot(df['Sale Quantity'])

# %% [markdown]
# Sales quantity has lot of fluctuations. Still has an increasing trend.

# %% [markdown]
# 4. Forecasting using 12 months Moving Average. Use the rolling() and shift()functions of Pandas. rolling() has a parameter "window" for indicating the time period to be used for forecasting. shift(1) indicates calculate 12 months moving average starting from previous month. Round the forecasted values to two decimal places.

# %%
df['mavg_12']=df['Sale Quantity'].rolling(window=12).mean().shift(1)
pd.options.display.float_format='{:.2f}'.format

# %% [markdown]
# 5. Print the forecasted sales from month 37 onwards

# %%
df[['Sale Quantity','mavg_12']][36:]
# Out:
#     Sale Quantity    mavg_12
# 36        3216483 3928410.33
# 37        3453239 3810280.00
# 38        5431651 3783643.33
# 39        4241851 3970688.42
# 40        3909887 4066369.08
# 41        3216438 4012412.75
# 42        4222005 3962369.58
# 43        3621034 3946629.42
# 44        5162201 3940489.50
# 45        4627177 4052117.17
# 46        4623945 4130274.75
# 47        4599368 4204882.33

# %% [markdown]
# 6. Plot the actual versus predicted values from moving average forecasting

# %%
plt.figure(figsize=(12,5))
plt.xlabel('Months')
plt.ylabel('Sale Quantity')
x=df['Sale Quantity'][12:]
y=df['mavg_12'][12:]
plt.plot(x)
plt.plot(y,"-")
plt.show()

# %% [markdown]
# 7. Calculate forecast accuracy, using RMSE

# %%
from sklearn.metrics import mean_squared_error
import numpy as np
x=df['Sale Quantity'][36:]
y=df['mavg_12'][36:]
np.sqrt(mean_squared_error(x,y))
# Out:
# 734725.8359239782

# %% [markdown]
# 8. Forecast "Sales Quantity" using Exponential Smoothing. The ewm() method in Pandas has features for computing exponential smoothing with "alpha" as a parameter.

# %%
df['esm']=df['Sale Quantity'].ewm(alpha=0.2).mean()
pd.options.display.float_format='{:.2f}'.format
df[36:][['Month','Sale Quantity','mavg_12','esm']]#Exponential smoothinening method
# Out:
#     Month  Sale Quantity    mavg_12        esm
# 36     37        3216483 3928410.33 3828234.64
# 37     38        3453239 3810280.00 3753219.93
# 38     39        5431651 3783643.33 4088961.93
# 39     40        4241851 3970688.42 4119543.81
# 40     41        3909887 4066369.08 4077607.99
# 41     42        3216438 4012412.75 3905359.34
# 42     43        4222005 3962369.58 3968692.78
# 43     44        3621034 3946629.42 3899157.24
# 44     45        5162201 3940489.50 4151776.99
# 45     46        4627177 4052117.17 4246860.31
# 46     47        4623945 4130274.75 4322279.35
# 47     48        4599368 4204882.33 4377698.31

# %% [markdown]
# 9. Calculate the forecast accuracy by exponential smoothing and compare it with that of moving average

# %%
from sklearn.metrics import mean_squared_error
import numpy as np
x=df['Sale Quantity'][36:]
y=df['esm'][36:]
np.sqrt(mean_squared_error(x,y))
# Out:
# 593857.5336904248

# %% [markdown]
# Comparing the RMSE of the two forecasting techniques namely Moving Average and Exponential Smoothing, we can understand, that predictions made by Exponential Smoothing has less standard deviation from the actual values.

# %% [markdown]
# # **Association_Rule_Mining**

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-44bbc229-cf6c-48d2-9ed4-ce42d15fffea" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-44bbc229-cf6c-48d2-9ed4-ce42d15fffea">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving groceries.csv to groceries.csv

# %% [markdown]
# 2.Read each row from the file and create a list of transactions.

# %%
all_txns = []
f = open("/content/groceries.csv","r")
content = f.readlines()
txns = [x.strip() for x in content]
for each_txn in txns:
  t = each_txn.split(',')
  t1 = [item for item in t if item !='']
  all_txns.append(t1)
print(all_txns[0:5])
# Out:
# [['citrus fruit', 'semi-finished bread', 'margarine', 'ready soups'], ['tropical fruit', 'yogurt', 'coffee'], ['whole milk'], ['pip fruit', 'yogurt', 'cream cheese', 'meat spreads'], ['other vegetables', 'whole milk', 'condensed milk', 'long life bakery product']]

# %% [markdown]
# 3.The method mlxtend generates association rules. For this method, the transactions have to be converted into a matrix format M x N, where M is the total no. of transactions and N is the no. of unique items in the transaction.The mlextend library has a pre-processing class called OnehotTransactions that will take all_txns as input and convert them into one-hot-encoded format.

# %%
import pandas as pd
import numpy as np
from mlxtend.preprocessing import OnehotTransactions
from mlxtend.frequent_patterns import apriori, association_rules
ohe = OnehotTransactions()
oht = ohe.fit(all_txns).transform(all_txns)
ohe_df = pd.DataFrame(oht, columns = ohe.columns_)
ohe_df.iloc[5:10, 10:20]
# Out:
# /usr/local/lib/python3.7/dist-packages/mlxtend/preprocessing/onehot.py:66: DeprecationWarning: OnehotTransactions has been deprecated and will be removed in future. Please use TransactionEncoder instead.
#   warnings.warn(msg, DeprecationWarning)
#    berries  beverages  bottled beer  ...  butter milk  cake bar  candles
# 5    False      False         False  ...        False     False    False
# 6    False      False         False  ...        False     False    False
# 7    False      False          True  ...        False     False    False
# 8    False      False         False  ...        False     False    False
# 9    False      False         False  ...        False     False    False
#
# [5 rows x 10 columns]

# %% [markdown]
# It can be seen that transaction-id 5 contains "butter".

# %%
ohe_df.shape
# Out:
# (9835, 169)

# %% [markdown]
# 4.Generating Frequent Itemsets using the Apriori. It takes the following parameters : df - one-hot encoded data frame ; min_support - a value between 0 to 1. Default is 0.5; use_colnames - if set to true uses the column names of df instead of column indices.

# %%
freq_itemsets = apriori(ohe_df, min_support = 0.02, use_colnames = True)
freq_itemsets.sample(10, random_state = 90)
# Out:
#       support                            itemsets
# 60   0.020437          (whole milk, bottled beer)
# 52   0.033859                             (sugar)
# 89   0.035892  (other vegetables, tropical fruit)
# 105  0.021047   (tropical fruit, root vegetables)
# 88   0.032740            (soda, other vegetables)
# 16   0.058058                            (coffee)
# 111  0.024504         (whole milk, shopping bags)
# 36   0.079817                        (newspapers)
# 119  0.056024                (whole milk, yogurt)
# 55   0.071683                (whipped/sour cream)

# %% [markdown]
# 5.Generate the association rules using the association_rules(). Parameters are - df - the data frame ; metric - 'lift'. min_threshold - minimum threshold for the evaluation metric to decide whether a candidate rule is of interest.

# %%
rules = association_rules(freq_itemsets, metric = "lift", min_threshold = 1)

# %% [markdown]
# 6.Print any 5 rules

# %%
rules.sample(5,random_state = 3)
# Out:
#                  antecedents         consequents  ...  leverage  conviction
# 42        (other vegetables)            (pastry)  ...  0.005358    1.031347
# 105         (tropical fruit)        (whole milk)  ...  0.015486    1.247252
# 5               (rolls/buns)     (bottled water)  ...  0.003870    1.024228
# 35   (fruit/vegetable juice)  (other vegetables)  ...  0.007059    1.137751
# 77         (root vegetables)        (rolls/buns)  ...  0.004252    1.050206
#
# [5 rows x 9 columns]

# %% [markdown]
# 7.Print top 10 rules based on rule evaluation metric "confidence"

# %%
rules.sort_values('confidence', ascending = False)[0:10]
# Out:
#                              antecedents  ... conviction
# 120           (yogurt, other vegetables)  ...   1.528340
# 17                              (butter)  ...   1.480817
# 25                                (curd)  ...   1.461085
# 116  (other vegetables, root vegetables)  ...   1.457687
# 115        (whole milk, root vegetables)  ...   1.533320
# 29                       (domestic eggs)  ...   1.412030
# 109                 (whipped/sour cream)  ...   1.352735
# 91                     (root vegetables)  ...   1.350401
# 51                     (root vegetables)  ...   1.426693
# 33                   (frozen vegetables)  ...   1.294636
#
# [10 rows x 9 columns]

# %% [markdown]
# # **Collaborative Filtering**

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-df304b30-e5b7-44a6-9bf7-8fbe0225815f" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-df304b30-e5b7-44a6-9bf7-8fbe0225815f">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving rating.csv to rating (2).csv

# %%
import pandas as pd

# %%
df = pd.read_csv("/content/rating (2).csv")

# %%
df.head(5)
# Out:
#    userId  movieId  rating         timestamp
# 0       1        2     3.5  02-04-2005 23:53
# 1       1       29     3.5  02-04-2005 23:31
# 2       1       32     3.5  02-04-2005 23:33
# 3       1       47     3.5  02-04-2005 23:32
# 4       1       50     3.5  02-04-2005 23:29

# %%
#df.drop('timestamp' , axis=1 , inplace = True)
print("No of uniquie users",len(df['userId'].unique()))
print("No of uniquie movies",len(df['movieId'].unique()))
# Out:
# No of uniquie users 7120
# No of uniquie movies 14026

# %%
user_movies_df = df.pivot(index = "userId", columns = "movieId",values="rating").reset_index(drop=True)
user_movies_df.index = df.userId.unique()
user_movies_df.fillna(0,inplace=True)

# %%
from sklearn.metrics import pairwise_distances
from scipy.spatial.distance import cosine,correlation
user_sim = 1 - pairwise_distances(user_movies_df.values, metric = "cosine")
#covert this matrix to a frame
user_sim_df = pd.DataFrame(user_sim)
#set the index and column names to user ids
user_sim_df.index = df.userId.unique()
user_sim_df.columns = df.userId.unique()
user_sim_df.iloc[0:5, 0:5]
# Out:
#           1         2         3         4         5
# 1  1.000000  0.102916  0.261198  0.029091  0.139199
# 2  0.102916  1.000000  0.180124  0.064014  0.140042
# 3  0.261198  0.180124  1.000000  0.057323  0.156755
# 4  0.029091  0.064014  0.057323  1.000000  0.300828
# 5  0.139199  0.140042  0.156755  0.300828  1.000000

# %%
import numpy as np
np.fill_diagonal(user_sim,0)
user_sim_df.iloc[0:5,0:5]
# Out:
#           1         2         3         4         5
# 1  0.000000  0.102916  0.261198  0.029091  0.139199
# 2  0.102916  0.000000  0.180124  0.064014  0.140042
# 3  0.261198  0.180124  0.000000  0.057323  0.156755
# 4  0.029091  0.064014  0.057323  0.000000  0.300828
# 5  0.139199  0.140042  0.156755  0.300828  0.000000

# %%
user_sim_df.idxmax(axis=1)[0:5]
# Out:
# 1    2595
# 2    5964
# 3     475
# 4     242
# 5    1367
# dtype: int64

# %%
movies_df = pd.read_csv("/content/movie.csv")
movies_df.drop('genres',axis=1,inplace=True)
movies_df.iloc[0:5,0:5]
# Out:
#    movieId                               title
# 0        1                    Toy Story (1995)
# 1        2                      Jumanji (1995)
# 2        3             Grumpier Old Men (1995)
# 3        4            Waiting to Exhale (1995)
# 4        5  Father of the Bride Part II (1995)

# %%
def get_user_similar_movies(user1,user2):
  #Inner of movies watched by both users will give the common movies
  common = df[df.userId == user1].merge(df[df.userId == user2], on="movieId",how="inner")
  #merge this result with movie details
  return common.merge(movies_df,on="movieId")

# %%
common_movies = get_user_similar_movies(1,2595)
#print(common_movies)
common_movies[(common_movies.rating_x >=4.0) & ((common_movies.rating_y >=0.4))]
# Out:
#     userId_x  ...                                              title
# 2          1  ...                                     Rob Roy (1995)
# 3          1  ...          Star Wars: Episode IV - A New Hope (1977)
# 4          1  ...  Léon: The Professional (a.k.a. The Professiona...
# 5          1  ...                                Pulp Fiction (1994)
# 6          1  ...                   Shawshank Redemption, The (1994)
# 7          1  ...                                Blade Runner (1982)
# 12         1  ...                                    Die Hard (1988)
# 13         1  ...                  E.T. the Extra-Terrestrial (1982)
# 16         1  ...  Star Wars: Episode V - The Empire Strikes Back...
# 17         1  ...  Raiders of the Lost Ark (Indiana Jones and the...
# 18         1  ...                                      Aliens (1986)
# 20         1  ...                                       Alien (1979)
# 21         1  ...                            Army of Darkness (1993)
# ...

# %%
2.4.Agglomerative Clustering with complete linkage

[63]
0s
n_clusters_single=AgglomerativeClustering(5,linkage="complete")
n_clusters_single.fit(scaled_df)
df['n_complete_cluster_id']=n_clusters_single.labels_
[74]
0s
print(df[df['n_complete_cluster_id']==0])
      Id  SepalLengthCm  ...  n_single_cluster_id  n_complete_cluster_id
41    42            4.5  ...                    3                      0
53    54            5.5  ...                    0                      0
55    56            5.7  ...                    0                      0
57    58            4.9  ...                    0                      0
59    60            5.2  ...                    0                      0
60    61            5.0  ...                    0                      0
62    63            6.0  ...                    0                      0
67    68            5.8  ...                    0                      0
68    69            6.2  ...                    0                      0
69    70            5.6  ...                    0                      0
79    80            5.7  ...                    0                      0
80    81            5.5  ...                    0                      0
81    82            5.5  ...                    0                      0
82    83            5.8  ...                    0                      0
87    88            6.3  ...                    0                      0
89    90            5.5  ...                    0                      0
90    91            5.5  ...                    0                      0
92    93            5.8  ...                    0                      0
93    94            5.0  ...                    0                      0
94    95            5.6  ...                    0                      0
98    99            5.1  ...                    0                      0
99   100            5.7  ...                    0                      0
106  107            4.9  ...                    0                      0
119  120            6.0  ...                    0                      0

[24 rows x 9 columns]
[75]
0s
print(df[df['n_complete_cluster_id']==1])
      Id  SepalLengthCm  ...  n_single_cluster_id  n_complete_cluster_id
105  106            7.6  ...                    0                      1
107  108            7.3  ...                    0                      1
109  110            7.2  ...                    4                      1
117  118            7.7  ...                    1                      1
118  119            7.7  ...                    0                      1
122  123            7.7  ...                    0                      1
125  126            7.2  ...                    0                      1
129  130            7.2  ...                    0                      1
130  131            7.4  ...                    0                      1
131  132            7.9  ...                    1                      1
135  136            7.7  ...                    0                      1

[11 rows x 9 columns]
[76]
0s
print(df[df['n_complete_cluster_id']==2])
    Id  SepalLengthCm  ...  n_single_cluster_id  n_complete_cluster_id
0    1            5.1  ...                    2                      2
1    2            4.9  ...                    2                      2
2    3            4.7  ...                    2                      2
3    4            4.6  ...                    2                      2
4    5            5.0  ...                    2                      2
6    7            4.6  ...                    2                      2
7    8            5.0  ...                    2                      2
8    9            4.4  ...                    2                      2
9   10            4.9  ...                    2                      2
10  11            5.4  ...                    2                      2
11  12            4.8  ...                    2                      2
12  13            4.8  ...                    2                      2
13  14            4.3  ...                    2                      2
17  18            5.1  ...                    2                      2
19  20            5.1  ...                    2                      2
20  21            5.4  ...                    2                      2
21  22            5.1  ...                    2                      2
22  23            4.6  ...                    2                      2
23  24            5.1  ...                    2                      2
24  25            4.8  ...                    2                      2
25  26            5.0  ...                    2                      2
26  27            5.0  ...                    2                      2
27  28            5.2  ...                    2                      2
28  29            5.2  ...                    2                      2
29  30            4.7  ...                    2                      2
30  31            4.8  ...                    2                      2
31  32            5.4  ...                    2                      2
34  35            4.9  ...                    2                      2
35  36            5.0  ...                    2                      2
36  37            5.5  ...                    2                      2
37  38            4.9  ...                    2                      2
38  39            4.4  ...                    2                      2
39  40            5.1  ...                    2                      2
40  41            5.0  ...                    2                      2
42  43            4.4  ...                    2                      2
43  44            5.0  ...                    2                      2
44  45            5.1  ...                    2                      2
45  46            4.8  ...                    2                      2
46  47            5.1  ...                    2                      2
47  48            4.6  ...                    2                      2
48  49            5.3  ...                    2                      2
49  50            5.0  ...                    2                      2

[42 rows x 9 columns]
[77]
0s
print(df[df['n_complete_cluster_id']==3])
      Id  SepalLengthCm  ...  n_single_cluster_id  n_complete_cluster_id
50    51            7.0  ...                    0                      3
51    52            6.4  ...                    0                      3
52    53            6.9  ...                    0                      3
54    55            6.5  ...                    0                      3
56    57            6.3  ...                    0                      3
..   ...            ...  ...                  ...                    ...
145  146            6.7  ...                    0                      3
146  147            6.3  ...                    0                      3
147  148            6.5  ...                    0                      3
148  149            6.2  ...                    0                      3
149  150            5.9  ...                    0                      3

[66 rows x 9 columns]
[78]
0s
print(df[df['n_complete_cluster_id']==4])
    Id  SepalLengthCm  ...  n_single_cluster_id  n_complete_cluster_id
5    6            5.4  ...                    2                      4
14  15            5.8  ...                    2                      4
15  16            5.7  ...                    2                      4
16  17            5.4  ...                    2                      4
18  19            5.7  ...                    2                      4
32  33            5.2  ...                    2                      4
33  34            5.5  ...                    2                      4

[7 rows x 9 columns]

# %%
print(df[df['n_complete_cluster_id']==3])
# Out:
#       Id  SepalLengthCm  ...  n_single_cluster_id  n_complete_cluster_id
# 50    51            7.0  ...                    0                      3
# 51    52            6.4  ...                    0                      3
# 52    53            6.9  ...                    0                      3
# 54    55            6.5  ...                    0                      3
# 56    57            6.3  ...                    0                      3
# ..   ...            ...  ...                  ...                    ...
# 145  146            6.7  ...                    0                      3
# 146  147            6.3  ...                    0                      3
# 147  148            6.5  ...                    0                      3
# 148  149            6.2  ...                    0                      3
# 149  150            5.9  ...                    0                      3
#
# [66 rows x 9 columns]

# %%
print(df[df['n_complete_cluster_id']==4])
# Out:
#     Id  SepalLengthCm  ...  n_single_cluster_id  n_complete_cluster_id
# 5    6            5.4  ...                    2                      4
# 14  15            5.8  ...                    2                      4
# 15  16            5.7  ...                    2                      4
# 16  17            5.4  ...                    2                      4
# 18  19            5.7  ...                    2                      4
# 32  33            5.2  ...                    2                      4
# 33  34            5.5  ...                    2                      4
#
# [7 rows x 9 columns]
